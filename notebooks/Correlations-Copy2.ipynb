# %%
import numpy as np
from tensorflow.keras.models import Model, load_model
import tensorflow.keras.backend as K
from scipy.stats import pearsonr, spearmanr
import matplotlib.pyplot as plt
import sys
sys.path.append('../python_scripts/')
import correlations
sys.path.append('../imported_code/svcca/')
import cca_core, pwcca

x_predict, y_predict = correlations.make_test_data()
# Out:
# Making test data...
# Done!

# %%
'''
RSA: Create an RDM for each activation layer (90 total) and get correlations between pairings of RDMs
'''
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Flatten
from scipy.stats import pearsonr, spearmanr

# Function to correlate 2 RDMs
def correlate(RDM_1, RDM_2):
    print('Making correlations...')
    assert len(RDM_1) == len(RDM_2)
    num_unique_entries = 499500 # for 1000x1000
    arr_1 = np.empty((num_unique_entries))
    arr_2 = np.empty((num_unique_entries))
    counter = 0
    # first flatten all the relevant values
    for i in range(len(RDM_1)): #1000
        for j in range(i + 1, len(RDM_1)):
            arr_1[counter] = RDM_1[i, j]
            arr_2[counter] = RDM_2[i, j]
            counter += 1
    # Get Pearson correlation
    return pearsonr(arr_1, arr_2)[0]


num_images = len(x_predict) # 1000
RDM_list = np.empty((90, 1000, 1000)) #layer * instance, images, images
# Loop through network instances
for i in range(10):
    print('Working on model', str(i))
    K.clear_session()
    full_model = load_model('../outputs/models/primary/Version_4/all_cnn_c_instance_' + str(i) + '.h5')
    inp = full_model.input
    # Loop through layers
    for j in range(0, 9):
        print('Layer', str(j))
        out = full_model.layers[j].output
        # Flatten representation if needed
        if len(out.shape) != 2:
            out = Flatten()(out)
        temp_model = Model(inputs=inp, outputs=out)
        # Predict on x_predict, transpose for spearman
        print('Getting representation...')
        representations = temp_model.predict(x_predict).T
        print(representations.shape)
        print('Getting RDM...')
        RDM_list[10 * j + i] = spearmanr(representations, representations)[0][:num_images, :num_images]
        
print('Done gathering RDMs, now correlations')
correlations = np.empty((90, 90))
for i in range(correlations.shape[0]):
    for j in range(correlations.shape[1]):
        print('Correlation', str(i), ',', str(j))
        correlations[i, j] = correlate(RDM_list[i], RDM_list[j])

np.save('all_cnn_c_version_4_correlations.npy', correlations)
print('Done!')
# Out:
# Working on model 0
# Layer 0
# Getting representation...
# (98304, 1000)
# Getting RDM...
# Layer 1
# Getting representation...
# (98304, 1000)
# Getting RDM...
# Layer 2
# Getting representation...
# (24576, 1000)
# Getting RDM...
# Layer 3
# Getting representation...
# (49152, 1000)
# Getting RDM...
# Layer 4
# Getting representation...
# (49152, 1000)
# Getting RDM...
# Layer 5
# Getting representation...
# (12288, 1000)
# Getting RDM...
# Layer 6
# Getting representation...
# (6912, 1000)
# Getting RDM...
# Layer 7
# Getting representation...
# (6912, 1000)
# Getting RDM...
# Layer 8
# Getting representation...
# (360, 1000)
# Getting RDM...
# Working on model 1
# Layer 0
# Getting representation...
# (98304, 1000)
# Getting RDM...
# Layer 1
# Getting representation...
# (98304, 1000)
# Getting RDM...
# Layer 2
# Getting representation...
# (24576, 1000)
# Getting RDM...
# Layer 3
# Getting representation...
# (49152, 1000)
# Getting RDM...
# Layer 4
# Getting representation...
# (49152, 1000)
# Getting RDM...
# Layer 5
# Getting representation...
# (12288, 1000)
# Getting RDM...
# Layer 6
# Getting representation...
# (6912, 1000)
# Getting RDM...
# Layer 7
# Getting representation...
# (6912, 1000)
# Getting RDM...

# %%
import matplotlib.pyplot as plt
correlations = np.load('all_cnn_c_version_4_correlations.npy')
correlations_distance = 1 - correlations
plt.title('Correlation Distance')
plt.xlabel('layer')
plt.xticks(ticks=[5, 15, 25, 35, 45, 55, 65, 75, 85],
           labels=[1, 2, 3, 4, 5, 6, 7, 8, 9])
plt.yticks(ticks=[5, 15, 25, 35, 45, 55, 65, 75, 85],
           labels=[1, 2, 3, 4, 5, 6, 7, 8, 9])
plt.ylabel('layer')

plt.imshow(correlations_distance)
plt.colorbar()

# %%
from sklearn.manifold import MDS
embedding = MDS(n_components=2, dissimilarity='precomputed')
X_transformed = embedding.fit_transform(correlations_distance)
colors = ['#f5f59d', '#f5b642', '#f58742', '#f55442', '#c940c5',
          '#b407ed', '#7d09d6', '#50017a', '#000000']
plt.plot(X_transformed[::10, 0], X_transformed[::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[1::10, 0], X_transformed[1::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[2::10, 0], X_transformed[2::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[3::10, 0], X_transformed[3::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[4::10, 0], X_transformed[4::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[5::10, 0], X_transformed[5::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[6::10, 0], X_transformed[6::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[7::10, 0], X_transformed[7::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[8::10, 0], X_transformed[8::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[::10, 0], X_transformed[::10, 1], linestyle='-', color='black', zorder=1)

plt.scatter(X_transformed[::10, 0], X_transformed[::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[1::10, 0], X_transformed[1::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[2::10, 0], X_transformed[2::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[3::10, 0], X_transformed[3::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[4::10, 0], X_transformed[4::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[5::10, 0], X_transformed[5::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[6::10, 0], X_transformed[6::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[7::10, 0], X_transformed[7::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[8::10, 0], X_transformed[8::10, 1], marker='o', color=colors, zorder=2)

# %%
'''
SVCCA Pt. 1: Get flattened representations by avg pooling
'''

# For SVCCA, 1. prep data by avg pooling, 2. find threshold for each layer of each network
# 3. SVCCA each network with each other network, plot into graph


# Helper function to find threshold for each layer            
def search_threshold(acts):
    print('Getting threshold...')
    target = 0.99
    start = 0
    end = acts.shape[0]
    ans = -1
    while start <= end:
        mid = (start + end) // 2
        # Move to right side if target is 
        # greater. 
        s = np.linalg.svd(acts - np.mean(acts, axis=1, keepdims=True), full_matrices=False)[1]
        # Note: normally comparing floating points is a bad bad but the precision we need is low enough
        if (np.sum(s[:mid])/np.sum(s) <= target): 
            start = mid + 1;
        # Move left side. 
        else: 
            ans = mid; 
            end = mid - 1;
    # Prevent silent failure
    if ans == -1:
        raise
    print('Sanity check, achieved', np.sum(s[:ans])/np.sum(s), 'variance with', ans, 'neurons')
    return ans

num_images = len(x_predict) # 1000
num_networks = 10
num_layers = 9
rep_list = [[], [], [], [], [], [], [], [], []]
thresholds = np.empty((num_layers * num_networks))

# Loop through network instances
for i in range(num_networks):
    print('Working on model', str(i))
    K.clear_session()
    full_model = load_model('../outputs/models/primary/Version_4/all_cnn_c_instance_' + str(i) + '.h5')
    inp = full_model.input
    # Loop through layers
    for j in range(num_layers):
        print('Layer', str(j))
        out = full_model.layers[j].output
        temp_model = Model(inputs=inp, outputs=out)
        # Predict on x_predict
        print('Getting representation...')
        representations = temp_model.predict(x_predict)
        print('Old shape:', representations.shape)
        # Average pool along spacial dimensions, transpose to fit shape (imgs, neurons)
        if (len(representations.shape) > 2):
            avg = np.mean(representations, axis=(1,2)).T
            print('Avg shape:', avg.shape)
        else:
            avg = representations.T
            print('No need to flatten')
        rep_list[j].append(avg)
        thresholds[num_networks * j + i] = search_threshold(avg)
        
    '''
SVCCA Pt. 2: Run SVCCA on every pairing of flattened representations (90 total) and save results
'''

# Helper Function for svcca
def svcca(acts1, acts2, threshold1, threshold2):
    print('Running SVCCA...')

    # Mean subtract activations
    cacts1 = acts1 - np.mean(acts1, axis=1, keepdims=True)
    cacts2 = acts2 - np.mean(acts2, axis=1, keepdims=True)

    # Perform SVD
    U1, s1, V1 = np.linalg.svd(cacts1, full_matrices=False)
    U2, s2, V2 = np.linalg.svd(cacts2, full_matrices=False)
    svacts1 = np.dot(s1[:threshold1]*np.eye(threshold1), V1[:threshold1])
    svacts2 = np.dot(s2[:threshold2]*np.eye(threshold2), V2[:threshold2])
    print('acts1 shape:', svacts1.shape)
    print('acts2 shape:', svacts2.shape)
    svcca_results = cca_core.get_cca_similarity(svacts1, svacts2, epsilon=1e-10, verbose=False)['cca_coef1']
    return np.mean(svcca_results)
     
print('Done preprocessing representations and thresholds, now CCA')
cca_correlations = np.empty((num_layers * num_networks, num_layers * num_networks))
for i in range(cca_correlations.shape[0]):
    for j in range(cca_correlations.shape[1]):
        print('Correlation', str(i), ',', str(j))
        
        layer_i = i // num_networks
        network_i = i % num_networks
        layer_j = j // num_networks
        network_j = j % num_networks
        acts1 = rep_list[layer_i][network_i]
        acts2 = rep_list[layer_j][network_j]
        
        thresh1 = int(thresholds[i])
        thresh2 = int(thresholds[j])
        
        # Do svcca
        print('Thresholds:', str(thresh1), str(thresh2))
        cca_correlations[i, j] = svcca(acts1, acts2, thresh1, thresh2)

np.save('cca_correlations_version_4.npy', cca_correlations)
print('Done!')
# Out:
# Working on model 0
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99002934 variance with 85 neurons
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9901557 variance with 80 neurons
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99016666 variance with 80 neurons
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9904807 variance with 162 neurons
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9903277 variance with 164 neurons
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.990625 variance with 168 neurons
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9904673 variance with 176 neurons
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9902912 variance with 182 neurons
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Getting threshold...
# Sanity check, achieved 1.0 variance with 10 neurons
# Working on model 1
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9908365 variance with 85 neurons
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99005586 variance with 81 neurons
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99061584 variance with 78 neurons
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9903086 variance with 159 neurons
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9901371 variance with 161 neurons
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9901562 variance with 171 neurons
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99066645 variance with 179 neurons
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9911852 variance with 182 neurons
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Getting threshold...
# Sanity check, achieved 1.0 variance with 10 neurons
# Working on model 2
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99090976 variance with 85 neurons
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99053353 variance with 79 neurons
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99047136 variance with 77 neurons
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9900861 variance with 157 neurons
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99049723 variance with 155 neurons
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99013174 variance with 165 neurons
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9904696 variance with 174 neurons
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.990847 variance with 179 neurons
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Getting threshold...
# Sanity check, achieved 1.0 variance with 10 neurons
# Working on model 3
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9904909 variance with 85 neurons
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9902893 variance with 79 neurons
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9901258 variance with 74 neurons
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9901304 variance with 162 neurons
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99010724 variance with 166 neurons
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9905129 variance with 166 neurons
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9907428 variance with 177 neurons
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9903096 variance with 182 neurons
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Getting threshold...
# Sanity check, achieved 1.0 variance with 10 neurons
# Working on model 4
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9905218 variance with 86 neurons
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9904175 variance with 79 neurons
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9905387 variance with 77 neurons
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9903156 variance with 164 neurons
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9900322 variance with 168 neurons
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99003035 variance with 172 neurons
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99091035 variance with 181 neurons
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9909406 variance with 184 neurons
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Getting threshold...
# Sanity check, achieved 1.0 variance with 10 neurons
# Working on model 5
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99082804 variance with 86 neurons
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99076563 variance with 80 neurons
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.990253 variance with 79 neurons
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9904917 variance with 161 neurons
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9905675 variance with 165 neurons
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99012727 variance with 171 neurons
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9900802 variance with 174 neurons
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99036634 variance with 181 neurons
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Getting threshold...
# Sanity check, achieved 1.0 variance with 10 neurons
# Working on model 6
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9900719 variance with 84 neurons
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9907653 variance with 81 neurons
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9907128 variance with 76 neurons
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99026763 variance with 159 neurons
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9903402 variance with 167 neurons
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9902981 variance with 169 neurons
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9907635 variance with 175 neurons
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9910465 variance with 182 neurons
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Getting threshold...
# Sanity check, achieved 1.0 variance with 10 neurons
# Working on model 7
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99029994 variance with 85 neurons
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99030316 variance with 79 neurons
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99060035 variance with 78 neurons
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99002236 variance with 157 neurons
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99044687 variance with 158 neurons
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99064374 variance with 168 neurons
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99073076 variance with 175 neurons
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9907566 variance with 181 neurons
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Getting threshold...
# Sanity check, achieved 1.0 variance with 10 neurons
# Working on model 8
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9902088 variance with 85 neurons
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99002594 variance with 79 neurons
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99091715 variance with 79 neurons
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99011266 variance with 161 neurons
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9902605 variance with 163 neurons
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.990307 variance with 158 neurons
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.990371 variance with 169 neurons
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9904377 variance with 180 neurons
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Getting threshold...
# Sanity check, achieved 1.0 variance with 10 neurons
# Working on model 9
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.9901997 variance with 85 neurons
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99011123 variance with 81 neurons
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Getting threshold...
# Sanity check, achieved 0.99010056 variance with 78 neurons
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9904222 variance with 165 neurons
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99015945 variance with 162 neurons
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9903698 variance with 168 neurons
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.9900349 variance with 173 neurons
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Getting threshold...
# Sanity check, achieved 0.99093455 variance with 179 neurons
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Getting threshold...
# Sanity check, achieved 1.0 variance with 10 neurons
# Done preprocessing representations and thresholds, now CCA
# Correlation 0 , 0
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 0 , 1
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 0 , 2
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 0 , 3
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 0 , 4
# Thresholds: 85 86
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (86, 1000)
# Correlation 0 , 5
# Thresholds: 85 86
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (86, 1000)
# Correlation 0 , 6
# Thresholds: 85 84
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (84, 1000)
# Correlation 0 , 7
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 0 , 8
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 0 , 9
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 0 , 10
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 0 , 11
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 0 , 12
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 0 , 13
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 0 , 14
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 0 , 15
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 0 , 16
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 0 , 17
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 0 , 18
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 0 , 19
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 0 , 20
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 0 , 21
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 0 , 22
# Thresholds: 85 77
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (77, 1000)
# Correlation 0 , 23
# Thresholds: 85 74
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (74, 1000)
# Correlation 0 , 24
# Thresholds: 85 77
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (77, 1000)
# Correlation 0 , 25
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 0 , 26
# Thresholds: 85 76
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (76, 1000)
# Correlation 0 , 27
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 0 , 28
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 0 , 29
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 0 , 30
# Thresholds: 85 162
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (162, 1000)
# Correlation 0 , 31
# Thresholds: 85 159
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (159, 1000)
# Correlation 0 , 32
# Thresholds: 85 157
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (157, 1000)
# Correlation 0 , 33
# Thresholds: 85 162
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (162, 1000)
# Correlation 0 , 34
# Thresholds: 85 164
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (164, 1000)
# Correlation 0 , 35
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 0 , 36
# Thresholds: 85 159
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (159, 1000)
# Correlation 0 , 37
# Thresholds: 85 157
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (157, 1000)
# Correlation 0 , 38
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 0 , 39
# Thresholds: 85 165
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (165, 1000)
# Correlation 0 , 40
# Thresholds: 85 164
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (164, 1000)
# Correlation 0 , 41
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 0 , 42
# Thresholds: 85 155
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (155, 1000)
# Correlation 0 , 43
# Thresholds: 85 166
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (166, 1000)
# Correlation 0 , 44
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 0 , 45
# Thresholds: 85 165
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (165, 1000)
# Correlation 0 , 46
# Thresholds: 85 167
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (167, 1000)
# Correlation 0 , 47
# Thresholds: 85 158
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (158, 1000)
# Correlation 0 , 48
# Thresholds: 85 163
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (163, 1000)
# Correlation 0 , 49
# Thresholds: 85 162
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (162, 1000)
# Correlation 0 , 50
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 0 , 51
# Thresholds: 85 171
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (171, 1000)
# Correlation 0 , 52
# Thresholds: 85 165
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (165, 1000)
# Correlation 0 , 53
# Thresholds: 85 166
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (166, 1000)
# Correlation 0 , 54
# Thresholds: 85 172
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (172, 1000)
# Correlation 0 , 55
# Thresholds: 85 171
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (171, 1000)
# Correlation 0 , 56
# Thresholds: 85 169
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (169, 1000)
# Correlation 0 , 57
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 0 , 58
# Thresholds: 85 158
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (158, 1000)
# Correlation 0 , 59
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 0 , 60
# Thresholds: 85 176
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (176, 1000)
# Correlation 0 , 61
# Thresholds: 85 179
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (179, 1000)
# Correlation 0 , 62
# Thresholds: 85 174
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (174, 1000)
# Correlation 0 , 63
# Thresholds: 85 177
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (177, 1000)
# Correlation 0 , 64
# Thresholds: 85 181
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (181, 1000)
# Correlation 0 , 65
# Thresholds: 85 174
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (174, 1000)
# Correlation 0 , 66
# Thresholds: 85 175
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (175, 1000)
# Correlation 0 , 67
# Thresholds: 85 175
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (175, 1000)
# Correlation 0 , 68
# Thresholds: 85 169
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (169, 1000)
# Correlation 0 , 69
# Thresholds: 85 173
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (173, 1000)
# Correlation 0 , 70
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 0 , 71
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 0 , 72
# Thresholds: 85 179
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (179, 1000)
# Correlation 0 , 73
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 0 , 74
# Thresholds: 85 184
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (184, 1000)
# Correlation 0 , 75
# Thresholds: 85 181
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (181, 1000)
# Correlation 0 , 76
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 0 , 77
# Thresholds: 85 181
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (181, 1000)
# Correlation 0 , 78
# Thresholds: 85 180
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (180, 1000)
# Correlation 0 , 79
# Thresholds: 85 179
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (179, 1000)
# Correlation 0 , 80
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 0 , 81
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 0 , 82
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 0 , 83
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 0 , 84
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 0 , 85
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 0 , 86
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 0 , 87
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 0 , 88
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 0 , 89
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 1 , 0
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 1 , 1
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 1 , 2
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 1 , 3
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 1 , 4
# Thresholds: 85 86
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (86, 1000)
# Correlation 1 , 5
# Thresholds: 85 86
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (86, 1000)
# Correlation 1 , 6
# Thresholds: 85 84
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (84, 1000)
# Correlation 1 , 7
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 1 , 8
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 1 , 9
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 1 , 10
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 1 , 11
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 1 , 12
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 1 , 13
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 1 , 14
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 1 , 15
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 1 , 16
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 1 , 17
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 1 , 18
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 1 , 19
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 1 , 20
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 1 , 21
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 1 , 22
# Thresholds: 85 77
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (77, 1000)
# Correlation 1 , 23
# Thresholds: 85 74
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (74, 1000)
# Correlation 1 , 24
# Thresholds: 85 77
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (77, 1000)
# Correlation 1 , 25
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 1 , 26
# Thresholds: 85 76
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (76, 1000)
# Correlation 1 , 27
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 1 , 28
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 1 , 29
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 1 , 30
# Thresholds: 85 162
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (162, 1000)
# Correlation 1 , 31
# Thresholds: 85 159
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (159, 1000)
# Correlation 1 , 32
# Thresholds: 85 157
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (157, 1000)
# Correlation 1 , 33
# Thresholds: 85 162
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (162, 1000)
# Correlation 1 , 34
# Thresholds: 85 164
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (164, 1000)
# Correlation 1 , 35
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 1 , 36
# Thresholds: 85 159
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (159, 1000)
# Correlation 1 , 37
# Thresholds: 85 157
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (157, 1000)
# Correlation 1 , 38
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 1 , 39
# Thresholds: 85 165
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (165, 1000)
# Correlation 1 , 40
# Thresholds: 85 164
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (164, 1000)
# Correlation 1 , 41
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 1 , 42
# Thresholds: 85 155
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (155, 1000)
# Correlation 1 , 43
# Thresholds: 85 166
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (166, 1000)
# Correlation 1 , 44
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 1 , 45
# Thresholds: 85 165
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (165, 1000)
# Correlation 1 , 46
# Thresholds: 85 167
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (167, 1000)
# Correlation 1 , 47
# Thresholds: 85 158
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (158, 1000)
# Correlation 1 , 48
# Thresholds: 85 163
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (163, 1000)
# Correlation 1 , 49
# Thresholds: 85 162
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (162, 1000)
# Correlation 1 , 50
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 1 , 51
# Thresholds: 85 171
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (171, 1000)
# Correlation 1 , 52
# Thresholds: 85 165
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (165, 1000)
# Correlation 1 , 53
# Thresholds: 85 166
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (166, 1000)
# Correlation 1 , 54
# Thresholds: 85 172
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (172, 1000)
# Correlation 1 , 55
# Thresholds: 85 171
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (171, 1000)
# Correlation 1 , 56
# Thresholds: 85 169
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (169, 1000)
# Correlation 1 , 57
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 1 , 58
# Thresholds: 85 158
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (158, 1000)
# Correlation 1 , 59
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 1 , 60
# Thresholds: 85 176
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (176, 1000)
# Correlation 1 , 61
# Thresholds: 85 179
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (179, 1000)
# Correlation 1 , 62
# Thresholds: 85 174
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (174, 1000)
# Correlation 1 , 63
# Thresholds: 85 177
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (177, 1000)
# Correlation 1 , 64
# Thresholds: 85 181
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (181, 1000)
# Correlation 1 , 65
# Thresholds: 85 174
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (174, 1000)
# Correlation 1 , 66
# Thresholds: 85 175
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (175, 1000)
# Correlation 1 , 67
# Thresholds: 85 175
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (175, 1000)
# Correlation 1 , 68
# Thresholds: 85 169
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (169, 1000)
# Correlation 1 , 69
# Thresholds: 85 173
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (173, 1000)
# Correlation 1 , 70
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 1 , 71
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 1 , 72
# Thresholds: 85 179
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (179, 1000)
# Correlation 1 , 73
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 1 , 74
# Thresholds: 85 184
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (184, 1000)
# Correlation 1 , 75
# Thresholds: 85 181
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (181, 1000)
# Correlation 1 , 76
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 1 , 77
# Thresholds: 85 181
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (181, 1000)
# Correlation 1 , 78
# Thresholds: 85 180
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (180, 1000)
# Correlation 1 , 79
# Thresholds: 85 179
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (179, 1000)
# Correlation 1 , 80
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 1 , 81
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 1 , 82
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 1 , 83
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 1 , 84
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 1 , 85
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 1 , 86
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 1 , 87
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 1 , 88
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 1 , 89
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 2 , 0
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 2 , 1
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 2 , 2
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 2 , 3
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 2 , 4
# Thresholds: 85 86
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (86, 1000)
# Correlation 2 , 5
# Thresholds: 85 86
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (86, 1000)
# Correlation 2 , 6
# Thresholds: 85 84
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (84, 1000)
# Correlation 2 , 7
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 2 , 8
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 2 , 9
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 2 , 10
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 2 , 11
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 2 , 12
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 2 , 13
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 2 , 14
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 2 , 15
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 2 , 16
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 2 , 17
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 2 , 18
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 2 , 19
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 2 , 20
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 2 , 21
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 2 , 22
# Thresholds: 85 77
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (77, 1000)
# Correlation 2 , 23
# Thresholds: 85 74
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (74, 1000)
# Correlation 2 , 24
# Thresholds: 85 77
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (77, 1000)
# Correlation 2 , 25
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 2 , 26
# Thresholds: 85 76
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (76, 1000)
# Correlation 2 , 27
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 2 , 28
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 2 , 29
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 2 , 30
# Thresholds: 85 162
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (162, 1000)
# Correlation 2 , 31
# Thresholds: 85 159
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (159, 1000)
# Correlation 2 , 32
# Thresholds: 85 157
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (157, 1000)
# Correlation 2 , 33
# Thresholds: 85 162
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (162, 1000)
# Correlation 2 , 34
# Thresholds: 85 164
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (164, 1000)
# Correlation 2 , 35
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 2 , 36
# Thresholds: 85 159
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (159, 1000)
# Correlation 2 , 37
# Thresholds: 85 157
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (157, 1000)
# Correlation 2 , 38
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 2 , 39
# Thresholds: 85 165
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (165, 1000)
# Correlation 2 , 40
# Thresholds: 85 164
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (164, 1000)
# Correlation 2 , 41
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 2 , 42
# Thresholds: 85 155
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (155, 1000)
# Correlation 2 , 43
# Thresholds: 85 166
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (166, 1000)
# Correlation 2 , 44
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 2 , 45
# Thresholds: 85 165
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (165, 1000)
# Correlation 2 , 46
# Thresholds: 85 167
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (167, 1000)
# Correlation 2 , 47
# Thresholds: 85 158
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (158, 1000)
# Correlation 2 , 48
# Thresholds: 85 163
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (163, 1000)
# Correlation 2 , 49
# Thresholds: 85 162
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (162, 1000)
# Correlation 2 , 50
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 2 , 51
# Thresholds: 85 171
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (171, 1000)
# Correlation 2 , 52
# Thresholds: 85 165
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (165, 1000)
# Correlation 2 , 53
# Thresholds: 85 166
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (166, 1000)
# Correlation 2 , 54
# Thresholds: 85 172
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (172, 1000)
# Correlation 2 , 55
# Thresholds: 85 171
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (171, 1000)
# Correlation 2 , 56
# Thresholds: 85 169
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (169, 1000)
# Correlation 2 , 57
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 2 , 58
# Thresholds: 85 158
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (158, 1000)
# Correlation 2 , 59
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 2 , 60
# Thresholds: 85 176
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (176, 1000)
# Correlation 2 , 61
# Thresholds: 85 179
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (179, 1000)
# Correlation 2 , 62
# Thresholds: 85 174
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (174, 1000)
# Correlation 2 , 63
# Thresholds: 85 177
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (177, 1000)
# Correlation 2 , 64
# Thresholds: 85 181
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (181, 1000)
# Correlation 2 , 65
# Thresholds: 85 174
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (174, 1000)
# Correlation 2 , 66
# Thresholds: 85 175
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (175, 1000)
# Correlation 2 , 67
# Thresholds: 85 175
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (175, 1000)
# Correlation 2 , 68
# Thresholds: 85 169
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (169, 1000)
# Correlation 2 , 69
# Thresholds: 85 173
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (173, 1000)
# Correlation 2 , 70
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 2 , 71
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 2 , 72
# Thresholds: 85 179
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (179, 1000)
# Correlation 2 , 73
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 2 , 74
# Thresholds: 85 184
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (184, 1000)
# Correlation 2 , 75
# Thresholds: 85 181
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (181, 1000)
# Correlation 2 , 76
# Thresholds: 85 182
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (182, 1000)
# Correlation 2 , 77
# Thresholds: 85 181
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (181, 1000)
# Correlation 2 , 78
# Thresholds: 85 180
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (180, 1000)
# Correlation 2 , 79
# Thresholds: 85 179
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (179, 1000)
# Correlation 2 , 80
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 2 , 81
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 2 , 82
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 2 , 83
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 2 , 84
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 2 , 85
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 2 , 86
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 2 , 87
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 2 , 88
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 2 , 89
# Thresholds: 85 10
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (10, 1000)
# Correlation 3 , 0
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 3 , 1
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 3 , 2
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 3 , 3
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 3 , 4
# Thresholds: 85 86
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (86, 1000)
# Correlation 3 , 5
# Thresholds: 85 86
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (86, 1000)
# Correlation 3 , 6
# Thresholds: 85 84
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (84, 1000)
# Correlation 3 , 7
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 3 , 8
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 3 , 9
# Thresholds: 85 85
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (85, 1000)
# Correlation 3 , 10
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 3 , 11
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 3 , 12
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 3 , 13
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 3 , 14
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 3 , 15
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 3 , 16
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 3 , 17
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 3 , 18
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 3 , 19
# Thresholds: 85 81
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (81, 1000)
# Correlation 3 , 20
# Thresholds: 85 80
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (80, 1000)
# Correlation 3 , 21
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 3 , 22
# Thresholds: 85 77
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (77, 1000)
# Correlation 3 , 23
# Thresholds: 85 74
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (74, 1000)
# Correlation 3 , 24
# Thresholds: 85 77
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (77, 1000)
# Correlation 3 , 25
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 3 , 26
# Thresholds: 85 76
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (76, 1000)
# Correlation 3 , 27
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 3 , 28
# Thresholds: 85 79
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (79, 1000)
# Correlation 3 , 29
# Thresholds: 85 78
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (78, 1000)
# Correlation 3 , 30
# Thresholds: 85 162
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (162, 1000)
# Correlation 3 , 31
# Thresholds: 85 159
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (159, 1000)
# Correlation 3 , 32
# Thresholds: 85 157
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (157, 1000)
# Correlation 3 , 33
# Thresholds: 85 162
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (162, 1000)
# Correlation 3 , 34
# Thresholds: 85 164
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (164, 1000)
# Correlation 3 , 35
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 3 , 36
# Thresholds: 85 159
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (159, 1000)
# Correlation 3 , 37
# Thresholds: 85 157
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (157, 1000)
# Correlation 3 , 38
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 3 , 39
# Thresholds: 85 165
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (165, 1000)
# Correlation 3 , 40
# Thresholds: 85 164
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (164, 1000)
# Correlation 3 , 41
# Thresholds: 85 161
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (161, 1000)
# Correlation 3 , 42
# Thresholds: 85 155
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (155, 1000)
# Correlation 3 , 43
# Thresholds: 85 166
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (166, 1000)
# Correlation 3 , 44
# Thresholds: 85 168
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (168, 1000)
# Correlation 3 , 45
# Thresholds: 85 165
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (165, 1000)
# Correlation 3 , 46
# Thresholds: 85 167
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (167, 1000)
# Correlation 3 , 47
# Thresholds: 85 158
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (158, 1000)
# Correlation 3 , 48
# Thresholds: 85 163
# Running SVCCA...
# acts1 shape: (85, 1000)
# acts2 shape: (163, 1000)
# Correlation 3 , 49
# ...
# acts2 shape: (76, 1000)
# Correlation 88 , 27
# Thresholds: 10 78
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (78, 1000)
# Correlation 88 , 28
# Thresholds: 10 79
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (79, 1000)
# Correlation 88 , 29
# Thresholds: 10 78
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (78, 1000)
# Correlation 88 , 30
# Thresholds: 10 162
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (162, 1000)
# Correlation 88 , 31
# Thresholds: 10 159
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (159, 1000)
# Correlation 88 , 32
# Thresholds: 10 157
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (157, 1000)
# Correlation 88 , 33
# Thresholds: 10 162
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (162, 1000)
# Correlation 88 , 34
# Thresholds: 10 164
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (164, 1000)
# Correlation 88 , 35
# Thresholds: 10 161
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (161, 1000)
# Correlation 88 , 36
# Thresholds: 10 159
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (159, 1000)
# Correlation 88 , 37
# Thresholds: 10 157
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (157, 1000)
# Correlation 88 , 38
# Thresholds: 10 161
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (161, 1000)
# Correlation 88 , 39
# Thresholds: 10 165
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (165, 1000)
# Correlation 88 , 40
# Thresholds: 10 164
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (164, 1000)
# Correlation 88 , 41
# Thresholds: 10 161
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (161, 1000)
# Correlation 88 , 42
# Thresholds: 10 155
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (155, 1000)
# Correlation 88 , 43
# Thresholds: 10 166
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (166, 1000)
# Correlation 88 , 44
# Thresholds: 10 168
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (168, 1000)
# Correlation 88 , 45
# Thresholds: 10 165
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (165, 1000)
# Correlation 88 , 46
# Thresholds: 10 167
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (167, 1000)
# Correlation 88 , 47
# Thresholds: 10 158
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (158, 1000)
# Correlation 88 , 48
# Thresholds: 10 163
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (163, 1000)
# Correlation 88 , 49
# Thresholds: 10 162
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (162, 1000)
# Correlation 88 , 50
# Thresholds: 10 168
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (168, 1000)
# Correlation 88 , 51
# Thresholds: 10 171
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (171, 1000)
# Correlation 88 , 52
# Thresholds: 10 165
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (165, 1000)
# Correlation 88 , 53
# Thresholds: 10 166
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (166, 1000)
# Correlation 88 , 54
# Thresholds: 10 172
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (172, 1000)
# Correlation 88 , 55
# Thresholds: 10 171
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (171, 1000)
# Correlation 88 , 56
# Thresholds: 10 169
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (169, 1000)
# Correlation 88 , 57
# Thresholds: 10 168
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (168, 1000)
# Correlation 88 , 58
# Thresholds: 10 158
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (158, 1000)
# Correlation 88 , 59
# Thresholds: 10 168
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (168, 1000)
# Correlation 88 , 60
# Thresholds: 10 176
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (176, 1000)
# Correlation 88 , 61
# Thresholds: 10 179
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (179, 1000)
# Correlation 88 , 62
# Thresholds: 10 174
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (174, 1000)
# Correlation 88 , 63
# Thresholds: 10 177
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (177, 1000)
# Correlation 88 , 64
# Thresholds: 10 181
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (181, 1000)
# Correlation 88 , 65
# Thresholds: 10 174
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (174, 1000)
# Correlation 88 , 66
# Thresholds: 10 175
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (175, 1000)
# Correlation 88 , 67
# Thresholds: 10 175
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (175, 1000)
# Correlation 88 , 68
# Thresholds: 10 169
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (169, 1000)
# Correlation 88 , 69
# Thresholds: 10 173
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (173, 1000)
# Correlation 88 , 70
# Thresholds: 10 182
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (182, 1000)
# Correlation 88 , 71
# Thresholds: 10 182
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (182, 1000)
# Correlation 88 , 72
# Thresholds: 10 179
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (179, 1000)
# Correlation 88 , 73
# Thresholds: 10 182
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (182, 1000)
# Correlation 88 , 74
# Thresholds: 10 184
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (184, 1000)
# Correlation 88 , 75
# Thresholds: 10 181
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (181, 1000)
# Correlation 88 , 76
# Thresholds: 10 182
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (182, 1000)
# Correlation 88 , 77
# Thresholds: 10 181
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (181, 1000)
# Correlation 88 , 78
# Thresholds: 10 180
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (180, 1000)
# Correlation 88 , 79
# Thresholds: 10 179
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (179, 1000)
# Correlation 88 , 80
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 88 , 81
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 88 , 82
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 88 , 83
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 88 , 84
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 88 , 85
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 88 , 86
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 88 , 87
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 88 , 88
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 88 , 89
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 89 , 0
# Thresholds: 10 85
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (85, 1000)
# Correlation 89 , 1
# Thresholds: 10 85
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (85, 1000)
# Correlation 89 , 2
# Thresholds: 10 85
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (85, 1000)
# Correlation 89 , 3
# Thresholds: 10 85
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (85, 1000)
# Correlation 89 , 4
# Thresholds: 10 86
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (86, 1000)
# Correlation 89 , 5
# Thresholds: 10 86
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (86, 1000)
# Correlation 89 , 6
# Thresholds: 10 84
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (84, 1000)
# Correlation 89 , 7
# Thresholds: 10 85
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (85, 1000)
# Correlation 89 , 8
# Thresholds: 10 85
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (85, 1000)
# Correlation 89 , 9
# Thresholds: 10 85
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (85, 1000)
# Correlation 89 , 10
# Thresholds: 10 80
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (80, 1000)
# Correlation 89 , 11
# Thresholds: 10 81
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (81, 1000)
# Correlation 89 , 12
# Thresholds: 10 79
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (79, 1000)
# Correlation 89 , 13
# Thresholds: 10 79
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (79, 1000)
# Correlation 89 , 14
# Thresholds: 10 79
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (79, 1000)
# Correlation 89 , 15
# Thresholds: 10 80
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (80, 1000)
# Correlation 89 , 16
# Thresholds: 10 81
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (81, 1000)
# Correlation 89 , 17
# Thresholds: 10 79
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (79, 1000)
# Correlation 89 , 18
# Thresholds: 10 79
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (79, 1000)
# Correlation 89 , 19
# Thresholds: 10 81
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (81, 1000)
# Correlation 89 , 20
# Thresholds: 10 80
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (80, 1000)
# Correlation 89 , 21
# Thresholds: 10 78
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (78, 1000)
# Correlation 89 , 22
# Thresholds: 10 77
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (77, 1000)
# Correlation 89 , 23
# Thresholds: 10 74
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (74, 1000)
# Correlation 89 , 24
# Thresholds: 10 77
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (77, 1000)
# Correlation 89 , 25
# Thresholds: 10 79
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (79, 1000)
# Correlation 89 , 26
# Thresholds: 10 76
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (76, 1000)
# Correlation 89 , 27
# Thresholds: 10 78
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (78, 1000)
# Correlation 89 , 28
# Thresholds: 10 79
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (79, 1000)
# Correlation 89 , 29
# Thresholds: 10 78
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (78, 1000)
# Correlation 89 , 30
# Thresholds: 10 162
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (162, 1000)
# Correlation 89 , 31
# Thresholds: 10 159
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (159, 1000)
# Correlation 89 , 32
# Thresholds: 10 157
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (157, 1000)
# Correlation 89 , 33
# Thresholds: 10 162
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (162, 1000)
# Correlation 89 , 34
# Thresholds: 10 164
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (164, 1000)
# Correlation 89 , 35
# Thresholds: 10 161
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (161, 1000)
# Correlation 89 , 36
# Thresholds: 10 159
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (159, 1000)
# Correlation 89 , 37
# Thresholds: 10 157
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (157, 1000)
# Correlation 89 , 38
# Thresholds: 10 161
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (161, 1000)
# Correlation 89 , 39
# Thresholds: 10 165
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (165, 1000)
# Correlation 89 , 40
# Thresholds: 10 164
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (164, 1000)
# Correlation 89 , 41
# Thresholds: 10 161
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (161, 1000)
# Correlation 89 , 42
# Thresholds: 10 155
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (155, 1000)
# Correlation 89 , 43
# Thresholds: 10 166
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (166, 1000)
# Correlation 89 , 44
# Thresholds: 10 168
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (168, 1000)
# Correlation 89 , 45
# Thresholds: 10 165
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (165, 1000)
# Correlation 89 , 46
# Thresholds: 10 167
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (167, 1000)
# Correlation 89 , 47
# Thresholds: 10 158
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (158, 1000)
# Correlation 89 , 48
# Thresholds: 10 163
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (163, 1000)
# Correlation 89 , 49
# Thresholds: 10 162
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (162, 1000)
# Correlation 89 , 50
# Thresholds: 10 168
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (168, 1000)
# Correlation 89 , 51
# Thresholds: 10 171
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (171, 1000)
# Correlation 89 , 52
# Thresholds: 10 165
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (165, 1000)
# Correlation 89 , 53
# Thresholds: 10 166
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (166, 1000)
# Correlation 89 , 54
# Thresholds: 10 172
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (172, 1000)
# Correlation 89 , 55
# Thresholds: 10 171
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (171, 1000)
# Correlation 89 , 56
# Thresholds: 10 169
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (169, 1000)
# Correlation 89 , 57
# Thresholds: 10 168
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (168, 1000)
# Correlation 89 , 58
# Thresholds: 10 158
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (158, 1000)
# Correlation 89 , 59
# Thresholds: 10 168
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (168, 1000)
# Correlation 89 , 60
# Thresholds: 10 176
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (176, 1000)
# Correlation 89 , 61
# Thresholds: 10 179
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (179, 1000)
# Correlation 89 , 62
# Thresholds: 10 174
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (174, 1000)
# Correlation 89 , 63
# Thresholds: 10 177
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (177, 1000)
# Correlation 89 , 64
# Thresholds: 10 181
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (181, 1000)
# Correlation 89 , 65
# Thresholds: 10 174
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (174, 1000)
# Correlation 89 , 66
# Thresholds: 10 175
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (175, 1000)
# Correlation 89 , 67
# Thresholds: 10 175
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (175, 1000)
# Correlation 89 , 68
# Thresholds: 10 169
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (169, 1000)
# Correlation 89 , 69
# Thresholds: 10 173
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (173, 1000)
# Correlation 89 , 70
# Thresholds: 10 182
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (182, 1000)
# Correlation 89 , 71
# Thresholds: 10 182
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (182, 1000)
# Correlation 89 , 72
# Thresholds: 10 179
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (179, 1000)
# Correlation 89 , 73
# Thresholds: 10 182
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (182, 1000)
# Correlation 89 , 74
# Thresholds: 10 184
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (184, 1000)
# Correlation 89 , 75
# Thresholds: 10 181
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (181, 1000)
# Correlation 89 , 76
# Thresholds: 10 182
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (182, 1000)
# Correlation 89 , 77
# Thresholds: 10 181
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (181, 1000)
# Correlation 89 , 78
# Thresholds: 10 180
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (180, 1000)
# Correlation 89 , 79
# Thresholds: 10 179
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (179, 1000)
# Correlation 89 , 80
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 89 , 81
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 89 , 82
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 89 , 83
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 89 , 84
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 89 , 85
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 89 , 86
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 89 , 87
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 89 , 88
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Correlation 89 , 89
# Thresholds: 10 10
# Running SVCCA...
# acts1 shape: (10, 1000)
# acts2 shape: (10, 1000)
# Done!

# %%
from matplotlib.pyplot import imshow
svcca_correlations = np.load('cca_correlations_version_4.npy')
svcca_correlations_distance = 1 - svcca_correlations
plt.title('Correlation Distance')
plt.xlabel('layer')
plt.xticks(ticks=[5, 15, 25, 35, 45, 55, 65, 75, 85],
           labels=[1, 2, 3, 4, 5, 6, 7, 8, 9])
plt.yticks(ticks=[5, 15, 25, 35, 45, 55, 65, 75, 85],
           labels=[1, 2, 3, 4, 5, 6, 7, 8, 9])
plt.ylabel('layer')

plt.imshow(svcca_correlations_distance)
plt.colorbar()

# %%
from sklearn.manifold import MDS
embedding = MDS(n_components=2, dissimilarity='precomputed')

X_transformed = embedding.fit_transform(svcca_correlations_distance)
X_transformed.shape

colors = ['#f5f59d', '#f5b642', '#f58742', '#f55442', '#c940c5',
          '#b407ed', '#7d09d6', '#50017a', '#000000']
plt.plot(X_transformed[::10, 0], X_transformed[::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[1::10, 0], X_transformed[1::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[2::10, 0], X_transformed[2::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[3::10, 0], X_transformed[3::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[4::10, 0], X_transformed[4::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[5::10, 0], X_transformed[5::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[6::10, 0], X_transformed[6::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[7::10, 0], X_transformed[7::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[8::10, 0], X_transformed[8::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[::10, 0], X_transformed[::10, 1], linestyle='-', color='black', zorder=1)

plt.scatter(X_transformed[::10, 0], X_transformed[::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[1::10, 0], X_transformed[1::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[2::10, 0], X_transformed[2::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[3::10, 0], X_transformed[3::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[4::10, 0], X_transformed[4::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[5::10, 0], X_transformed[5::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[6::10, 0], X_transformed[6::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[7::10, 0], X_transformed[7::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[8::10, 0], X_transformed[8::10, 1], marker='o', color=colors, zorder=2)

# %%
import pwcca

num_images = len(x_predict) # 1000
num_networks = 10
num_layers = 9
rep_list = [[], [], [], [], [], [], [], [], []]

# Loop through network instances
for i in range(num_networks):
    print('Working on model', str(i))
    K.clear_session()
    full_model = load_model('../outputs/models/primary/Version_4/all_cnn_c_instance_' + str(i) + '.h5')
    inp = full_model.input
    # Loop through layers
    for j in range(num_layers):
        print('Layer', str(j))
        out = full_model.layers[j].output
        temp_model = Model(inputs=inp, outputs=out)
        # Predict on x_predict
        print('Getting representation...')
        representations = temp_model.predict(x_predict)
        print('Old shape:', representations.shape)
        # Average pool along spacial dimensions, transpose to fit shape (imgs, neurons)
        if (len(representations.shape) > 2):
            avg = np.mean(representations, axis=(1,2)).T
            print('Avg shape:', avg.shape)
        else:
            avg = representations.T
            print('No need to flatten')
        rep_list[j].append(avg)
        
print('Done preprocessing representations and thresholds, now CCA')
pwcca_correlations = np.empty((num_layers * num_networks, num_layers * num_networks))
for i in range(pwcca_correlations.shape[0]):
    for j in range(pwcca_correlations.shape[1]):
        print('Correlation', str(i), ',', str(j))
        
        layer_i = i // num_networks
        network_i = i % num_networks
        layer_j = j // num_networks
        network_j = j % num_networks
        
        # pwcca is order-dependent, so swap around to make symmetric
        if (i >= j):
            acts1 = rep_list[layer_i][network_i]
            acts2 = rep_list[layer_j][network_j]
        else:
            acts1 = rep_list[layer_j][network_j]
            acts2 = rep_list[layer_i][network_i]        
        
        # Do pwcca, acts1 needs to have dim <= acts2
        if (acts1.shape[0] <= acts2.shape[0]):
            pwcca_correlations[i, j] = pwcca.compute_pwcca(acts1, acts2, epsilon=1e-10)[0]
        else:
            pwcca_correlations[i, j] = pwcca.compute_pwcca(acts2, acts1, epsilon=1e-10)[0]

np.save('pwcca_correlations.npy', pwcca_correlations)
print('Done!')
# Out:
# Working on model 0
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Working on model 1
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Working on model 2
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Working on model 3
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Working on model 4
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Working on model 5
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Working on model 6
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Working on model 7
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Working on model 8
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Working on model 9
# Layer 0
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 1
# Getting representation...
# Old shape: (1000, 32, 32, 96)
# Avg shape: (96, 1000)
# Layer 2
# Getting representation...
# Old shape: (1000, 16, 16, 96)
# Avg shape: (96, 1000)
# Layer 3
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 4
# Getting representation...
# Old shape: (1000, 16, 16, 192)
# Avg shape: (192, 1000)
# Layer 5
# Getting representation...
# Old shape: (1000, 8, 8, 192)
# Avg shape: (192, 1000)
# Layer 6
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 7
# Getting representation...
# Old shape: (1000, 6, 6, 192)
# Avg shape: (192, 1000)
# Layer 8
# Getting representation...
# Old shape: (1000, 6, 6, 10)
# Avg shape: (10, 1000)
# Done preprocessing representations and thresholds, now CCA
# Correlation 0 , 0
# Correlation 0 , 1
# Correlation 0 , 2
# Correlation 0 , 3
# Correlation 0 , 4
# Correlation 0 , 5
# Correlation 0 , 6
# Correlation 0 , 7
# Correlation 0 , 8
# Correlation 0 , 9
# Correlation 0 , 10
# Correlation 0 , 11
# Correlation 0 , 12
# Correlation 0 , 13
# Correlation 0 , 14
# Correlation 0 , 15
# Correlation 0 , 16
# Correlation 0 , 17
# Correlation 0 , 18
# Correlation 0 , 19
# Correlation 0 , 20
# Correlation 0 , 21
# Correlation 0 , 22
# Correlation 0 , 23
# Correlation 0 , 24
# Correlation 0 , 25
# Correlation 0 , 26
# Correlation 0 , 27
# Correlation 0 , 28
# Correlation 0 , 29
# Correlation 0 , 30
# Correlation 0 , 31
# Correlation 0 , 32
# Correlation 0 , 33
# Correlation 0 , 34
# Correlation 0 , 35
# Correlation 0 , 36
# Correlation 0 , 37
# Correlation 0 , 38
# Correlation 0 , 39
# Correlation 0 , 40
# Correlation 0 , 41
# Correlation 0 , 42
# Correlation 0 , 43
# Correlation 0 , 44
# Correlation 0 , 45
# Correlation 0 , 46
# Correlation 0 , 47
# Correlation 0 , 48
# Correlation 0 , 49
# Correlation 0 , 50
# Correlation 0 , 51
# Correlation 0 , 52
# Correlation 0 , 53
# Correlation 0 , 54
# Correlation 0 , 55
# Correlation 0 , 56
# Correlation 0 , 57
# Correlation 0 , 58
# Correlation 0 , 59
# Correlation 0 , 60
# Correlation 0 , 61
# Correlation 0 , 62
# Correlation 0 , 63
# Correlation 0 , 64
# Correlation 0 , 65
# Correlation 0 , 66
# Correlation 0 , 67
# Correlation 0 , 68
# Correlation 0 , 69
# Correlation 0 , 70
# Correlation 0 , 71
# Correlation 0 , 72
# Correlation 0 , 73
# Correlation 0 , 74
# Correlation 0 , 75
# Correlation 0 , 76
# Correlation 0 , 77
# Correlation 0 , 78
# Correlation 0 , 79
# Correlation 0 , 80
# Correlation 0 , 81
# Correlation 0 , 82
# Correlation 0 , 83
# Correlation 0 , 84
# Correlation 0 , 85
# Correlation 0 , 86
# Correlation 0 , 87
# Correlation 0 , 88
# Correlation 0 , 89
# Correlation 1 , 0
# Correlation 1 , 1
# Correlation 1 , 2
# Correlation 1 , 3
# Correlation 1 , 4
# Correlation 1 , 5
# Correlation 1 , 6
# Correlation 1 , 7
# Correlation 1 , 8
# Correlation 1 , 9
# Correlation 1 , 10
# Correlation 1 , 11
# Correlation 1 , 12
# Correlation 1 , 13
# Correlation 1 , 14
# Correlation 1 , 15
# Correlation 1 , 16
# Correlation 1 , 17
# Correlation 1 , 18
# Correlation 1 , 19
# Correlation 1 , 20
# Correlation 1 , 21
# Correlation 1 , 22
# Correlation 1 , 23
# Correlation 1 , 24
# Correlation 1 , 25
# Correlation 1 , 26
# Correlation 1 , 27
# Correlation 1 , 28
# Correlation 1 , 29
# Correlation 1 , 30
# Correlation 1 , 31
# Correlation 1 , 32
# Correlation 1 , 33
# Correlation 1 , 34
# Correlation 1 , 35
# Correlation 1 , 36
# Correlation 1 , 37
# Correlation 1 , 38
# Correlation 1 , 39
# Correlation 1 , 40
# Correlation 1 , 41
# Correlation 1 , 42
# Correlation 1 , 43
# Correlation 1 , 44
# Correlation 1 , 45
# Correlation 1 , 46
# Correlation 1 , 47
# Correlation 1 , 48
# Correlation 1 , 49
# Correlation 1 , 50
# Correlation 1 , 51
# Correlation 1 , 52
# Correlation 1 , 53
# Correlation 1 , 54
# Correlation 1 , 55
# Correlation 1 , 56
# Correlation 1 , 57
# Correlation 1 , 58
# Correlation 1 , 59
# Correlation 1 , 60
# Correlation 1 , 61
# Correlation 1 , 62
# Correlation 1 , 63
# Correlation 1 , 64
# Correlation 1 , 65
# Correlation 1 , 66
# Correlation 1 , 67
# Correlation 1 , 68
# Correlation 1 , 69
# Correlation 1 , 70
# Correlation 1 , 71
# Correlation 1 , 72
# Correlation 1 , 73
# Correlation 1 , 74
# Correlation 1 , 75
# Correlation 1 , 76
# Correlation 1 , 77
# Correlation 1 , 78
# Correlation 1 , 79
# Correlation 1 , 80
# Correlation 1 , 81
# Correlation 1 , 82
# Correlation 1 , 83
# Correlation 1 , 84
# Correlation 1 , 85
# Correlation 1 , 86
# Correlation 1 , 87
# Correlation 1 , 88
# Correlation 1 , 89
# Correlation 2 , 0
# Correlation 2 , 1
# Correlation 2 , 2
# Correlation 2 , 3
# Correlation 2 , 4
# Correlation 2 , 5
# Correlation 2 , 6
# Correlation 2 , 7
# Correlation 2 , 8
# Correlation 2 , 9
# Correlation 2 , 10
# Correlation 2 , 11
# Correlation 2 , 12
# Correlation 2 , 13
# Correlation 2 , 14
# Correlation 2 , 15
# Correlation 2 , 16
# Correlation 2 , 17
# Correlation 2 , 18
# Correlation 2 , 19
# Correlation 2 , 20
# Correlation 2 , 21
# Correlation 2 , 22
# Correlation 2 , 23
# Correlation 2 , 24
# Correlation 2 , 25
# Correlation 2 , 26
# Correlation 2 , 27
# Correlation 2 , 28
# Correlation 2 , 29
# Correlation 2 , 30
# Correlation 2 , 31
# Correlation 2 , 32
# Correlation 2 , 33
# Correlation 2 , 34
# Correlation 2 , 35
# Correlation 2 , 36
# Correlation 2 , 37
# Correlation 2 , 38
# Correlation 2 , 39
# Correlation 2 , 40
# Correlation 2 , 41
# Correlation 2 , 42
# Correlation 2 , 43
# Correlation 2 , 44
# Correlation 2 , 45
# Correlation 2 , 46
# Correlation 2 , 47
# Correlation 2 , 48
# Correlation 2 , 49
# Correlation 2 , 50
# Correlation 2 , 51
# Correlation 2 , 52
# Correlation 2 , 53
# Correlation 2 , 54
# Correlation 2 , 55
# Correlation 2 , 56
# Correlation 2 , 57
# Correlation 2 , 58
# Correlation 2 , 59
# Correlation 2 , 60
# Correlation 2 , 61
# Correlation 2 , 62
# Correlation 2 , 63
# Correlation 2 , 64
# Correlation 2 , 65
# Correlation 2 , 66
# Correlation 2 , 67
# Correlation 2 , 68
# Correlation 2 , 69
# Correlation 2 , 70
# Correlation 2 , 71
# Correlation 2 , 72
# Correlation 2 , 73
# Correlation 2 , 74
# Correlation 2 , 75
# Correlation 2 , 76
# Correlation 2 , 77
# Correlation 2 , 78
# Correlation 2 , 79
# Correlation 2 , 80
# Correlation 2 , 81
# Correlation 2 , 82
# Correlation 2 , 83
# Correlation 2 , 84
# Correlation 2 , 85
# Correlation 2 , 86
# Correlation 2 , 87
# Correlation 2 , 88
# Correlation 2 , 89
# Correlation 3 , 0
# Correlation 3 , 1
# Correlation 3 , 2
# Correlation 3 , 3
# Correlation 3 , 4
# Correlation 3 , 5
# Correlation 3 , 6
# Correlation 3 , 7
# Correlation 3 , 8
# Correlation 3 , 9
# Correlation 3 , 10
# Correlation 3 , 11
# Correlation 3 , 12
# Correlation 3 , 13
# Correlation 3 , 14
# Correlation 3 , 15
# Correlation 3 , 16
# Correlation 3 , 17
# Correlation 3 , 18
# Correlation 3 , 19
# Correlation 3 , 20
# Correlation 3 , 21
# Correlation 3 , 22
# Correlation 3 , 23
# Correlation 3 , 24
# Correlation 3 , 25
# Correlation 3 , 26
# Correlation 3 , 27
# Correlation 3 , 28
# Correlation 3 , 29
# Correlation 3 , 30
# Correlation 3 , 31
# Correlation 3 , 32
# Correlation 3 , 33
# Correlation 3 , 34
# Correlation 3 , 35
# Correlation 3 , 36
# Correlation 3 , 37
# Correlation 3 , 38
# Correlation 3 , 39
# Correlation 3 , 40
# Correlation 3 , 41
# Correlation 3 , 42
# Correlation 3 , 43
# Correlation 3 , 44
# Correlation 3 , 45
# Correlation 3 , 46
# Correlation 3 , 47
# Correlation 3 , 48
# Correlation 3 , 49
# Correlation 3 , 50
# Correlation 3 , 51
# Correlation 3 , 52
# Correlation 3 , 53
# Correlation 3 , 54
# Correlation 3 , 55
# Correlation 3 , 56
# Correlation 3 , 57
# Correlation 3 , 58
# Correlation 3 , 59
# Correlation 3 , 60
# Correlation 3 , 61
# Correlation 3 , 62
# Correlation 3 , 63
# Correlation 3 , 64
# Correlation 3 , 65
# Correlation 3 , 66
# Correlation 3 , 67
# Correlation 3 , 68
# Correlation 3 , 69
# Correlation 3 , 70
# Correlation 3 , 71
# Correlation 3 , 72
# Correlation 3 , 73
# Correlation 3 , 74
# Correlation 3 , 75
# Correlation 3 , 76
# Correlation 3 , 77
# Correlation 3 , 78
# Correlation 3 , 79
# Correlation 3 , 80
# Correlation 3 , 81
# Correlation 3 , 82
# Correlation 3 , 83
# Correlation 3 , 84
# Correlation 3 , 85
# Correlation 3 , 86
# Correlation 3 , 87
# Correlation 3 , 88
# Correlation 3 , 89
# Correlation 4 , 0
# Correlation 4 , 1
# Correlation 4 , 2
# Correlation 4 , 3
# Correlation 4 , 4
# Correlation 4 , 5
# Correlation 4 , 6
# Correlation 4 , 7
# Correlation 4 , 8
# Correlation 4 , 9
# Correlation 4 , 10
# Correlation 4 , 11
# Correlation 4 , 12
# Correlation 4 , 13
# Correlation 4 , 14
# Correlation 4 , 15
# Correlation 4 , 16
# Correlation 4 , 17
# Correlation 4 , 18
# Correlation 4 , 19
# Correlation 4 , 20
# Correlation 4 , 21
# Correlation 4 , 22
# Correlation 4 , 23
# Correlation 4 , 24
# Correlation 4 , 25
# Correlation 4 , 26
# Correlation 4 , 27
# Correlation 4 , 28
# Correlation 4 , 29
# Correlation 4 , 30
# Correlation 4 , 31
# Correlation 4 , 32
# Correlation 4 , 33
# Correlation 4 , 34
# Correlation 4 , 35
# Correlation 4 , 36
# Correlation 4 , 37
# Correlation 4 , 38
# Correlation 4 , 39
# Correlation 4 , 40
# Correlation 4 , 41
# Correlation 4 , 42
# Correlation 4 , 43
# Correlation 4 , 44
# Correlation 4 , 45
# Correlation 4 , 46
# Correlation 4 , 47
# Correlation 4 , 48
# Correlation 4 , 49
# Correlation 4 , 50
# Correlation 4 , 51
# Correlation 4 , 52
# Correlation 4 , 53
# Correlation 4 , 54
# Correlation 4 , 55
# Correlation 4 , 56
# Correlation 4 , 57
# Correlation 4 , 58
# Correlation 4 , 59
# Correlation 4 , 60
# Correlation 4 , 61
# Correlation 4 , 62
# Correlation 4 , 63
# Correlation 4 , 64
# Correlation 4 , 65
# Correlation 4 , 66
# Correlation 4 , 67
# Correlation 4 , 68
# Correlation 4 , 69
# Correlation 4 , 70
# Correlation 4 , 71
# Correlation 4 , 72
# Correlation 4 , 73
# Correlation 4 , 74
# Correlation 4 , 75
# Correlation 4 , 76
# Correlation 4 , 77
# Correlation 4 , 78
# Correlation 4 , 79
# Correlation 4 , 80
# Correlation 4 , 81
# Correlation 4 , 82
# Correlation 4 , 83
# Correlation 4 , 84
# Correlation 4 , 85
# Correlation 4 , 86
# Correlation 4 , 87
# Correlation 4 , 88
# Correlation 4 , 89
# Correlation 5 , 0
# Correlation 5 , 1
# Correlation 5 , 2
# Correlation 5 , 3
# Correlation 5 , 4
# Correlation 5 , 5
# Correlation 5 , 6
# Correlation 5 , 7
# Correlation 5 , 8
# Correlation 5 , 9
# Correlation 5 , 10
# Correlation 5 , 11
# Correlation 5 , 12
# Correlation 5 , 13
# Correlation 5 , 14
# Correlation 5 , 15
# Correlation 5 , 16
# Correlation 5 , 17
# Correlation 5 , 18
# Correlation 5 , 19
# Correlation 5 , 20
# Correlation 5 , 21
# Correlation 5 , 22
# Correlation 5 , 23
# Correlation 5 , 24
# Correlation 5 , 25
# Correlation 5 , 26
# Correlation 5 , 27
# Correlation 5 , 28
# Correlation 5 , 29
# Correlation 5 , 30
# Correlation 5 , 31
# Correlation 5 , 32
# Correlation 5 , 33
# Correlation 5 , 34
# Correlation 5 , 35
# Correlation 5 , 36
# Correlation 5 , 37
# Correlation 5 , 38
# Correlation 5 , 39
# Correlation 5 , 40
# Correlation 5 , 41
# Correlation 5 , 42
# Correlation 5 , 43
# Correlation 5 , 44
# Correlation 5 , 45
# Correlation 5 , 46
# Correlation 5 , 47
# Correlation 5 , 48
# Correlation 5 , 49
# Correlation 5 , 50
# Correlation 5 , 51
# Correlation 5 , 52
# Correlation 5 , 53
# Correlation 5 , 54
# Correlation 5 , 55
# Correlation 5 , 56
# Correlation 5 , 57
# Correlation 5 , 58
# Correlation 5 , 59
# Correlation 5 , 60
# Correlation 5 , 61
# Correlation 5 , 62
# Correlation 5 , 63
# Correlation 5 , 64
# Correlation 5 , 65
# Correlation 5 , 66
# Correlation 5 , 67
# Correlation 5 , 68
# Correlation 5 , 69
# Correlation 5 , 70
# Correlation 5 , 71
# Correlation 5 , 72
# Correlation 5 , 73
# Correlation 5 , 74
# Correlation 5 , 75
# Correlation 5 , 76
# Correlation 5 , 77
# Correlation 5 , 78
# Correlation 5 , 79
# Correlation 5 , 80
# Correlation 5 , 81
# Correlation 5 , 82
# Correlation 5 , 83
# Correlation 5 , 84
# Correlation 5 , 85
# Correlation 5 , 86
# Correlation 5 , 87
# Correlation 5 , 88
# Correlation 5 , 89
# Correlation 6 , 0
# Correlation 6 , 1
# Correlation 6 , 2
# Correlation 6 , 3
# Correlation 6 , 4
# Correlation 6 , 5
# Correlation 6 , 6
# Correlation 6 , 7
# Correlation 6 , 8
# Correlation 6 , 9
# Correlation 6 , 10
# Correlation 6 , 11
# Correlation 6 , 12
# Correlation 6 , 13
# Correlation 6 , 14
# Correlation 6 , 15
# Correlation 6 , 16
# Correlation 6 , 17
# Correlation 6 , 18
# Correlation 6 , 19
# Correlation 6 , 20
# Correlation 6 , 21
# Correlation 6 , 22
# Correlation 6 , 23
# Correlation 6 , 24
# Correlation 6 , 25
# Correlation 6 , 26
# Correlation 6 , 27
# Correlation 6 , 28
# Correlation 6 , 29
# Correlation 6 , 30
# Correlation 6 , 31
# Correlation 6 , 32
# Correlation 6 , 33
# Correlation 6 , 34
# Correlation 6 , 35
# Correlation 6 , 36
# Correlation 6 , 37
# Correlation 6 , 38
# Correlation 6 , 39
# Correlation 6 , 40
# Correlation 6 , 41
# Correlation 6 , 42
# Correlation 6 , 43
# Correlation 6 , 44
# Correlation 6 , 45
# Correlation 6 , 46
# Correlation 6 , 47
# Correlation 6 , 48
# Correlation 6 , 49
# Correlation 6 , 50
# Correlation 6 , 51
# Correlation 6 , 52
# Correlation 6 , 53
# Correlation 6 , 54
# Correlation 6 , 55
# Correlation 6 , 56
# Correlation 6 , 57
# Correlation 6 , 58
# Correlation 6 , 59
# Correlation 6 , 60
# Correlation 6 , 61
# Correlation 6 , 62
# Correlation 6 , 63
# Correlation 6 , 64
# Correlation 6 , 65
# Correlation 6 , 66
# Correlation 6 , 67
# Correlation 6 , 68
# Correlation 6 , 69
# Correlation 6 , 70
# Correlation 6 , 71
# Correlation 6 , 72
# Correlation 6 , 73
# Correlation 6 , 74
# Correlation 6 , 75
# Correlation 6 , 76
# Correlation 6 , 77
# Correlation 6 , 78
# Correlation 6 , 79
# Correlation 6 , 80
# Correlation 6 , 81
# Correlation 6 , 82
# Correlation 6 , 83
# Correlation 6 , 84
# Correlation 6 , 85
# Correlation 6 , 86
# Correlation 6 , 87
# Correlation 6 , 88
# Correlation 6 , 89
# Correlation 7 , 0
# Correlation 7 , 1
# Correlation 7 , 2
# Correlation 7 , 3
# Correlation 7 , 4
# Correlation 7 , 5
# Correlation 7 , 6
# Correlation 7 , 7
# Correlation 7 , 8
# Correlation 7 , 9
# Correlation 7 , 10
# Correlation 7 , 11
# Correlation 7 , 12
# Correlation 7 , 13
# Correlation 7 , 14
# Correlation 7 , 15
# Correlation 7 , 16
# Correlation 7 , 17
# Correlation 7 , 18
# Correlation 7 , 19
# Correlation 7 , 20
# Correlation 7 , 21
# Correlation 7 , 22
# Correlation 7 , 23
# Correlation 7 , 24
# Correlation 7 , 25
# Correlation 7 , 26
# Correlation 7 , 27
# Correlation 7 , 28
# Correlation 7 , 29
# Correlation 7 , 30
# Correlation 7 , 31
# Correlation 7 , 32
# Correlation 7 , 33
# Correlation 7 , 34
# Correlation 7 , 35
# Correlation 7 , 36
# Correlation 7 , 37
# Correlation 7 , 38
# Correlation 7 , 39
# Correlation 7 , 40
# Correlation 7 , 41
# Correlation 7 , 42
# Correlation 7 , 43
# Correlation 7 , 44
# Correlation 7 , 45
# Correlation 7 , 46
# Correlation 7 , 47
# Correlation 7 , 48
# Correlation 7 , 49
# Correlation 7 , 50
# Correlation 7 , 51
# Correlation 7 , 52
# Correlation 7 , 53
# Correlation 7 , 54
# Correlation 7 , 55
# Correlation 7 , 56
# Correlation 7 , 57
# Correlation 7 , 58
# Correlation 7 , 59
# Correlation 7 , 60
# Correlation 7 , 61
# Correlation 7 , 62
# Correlation 7 , 63
# Correlation 7 , 64
# Correlation 7 , 65
# Correlation 7 , 66
# Correlation 7 , 67
# Correlation 7 , 68
# Correlation 7 , 69
# Correlation 7 , 70
# Correlation 7 , 71
# Correlation 7 , 72
# Correlation 7 , 73
# Correlation 7 , 74
# Correlation 7 , 75
# Correlation 7 , 76
# Correlation 7 , 77
# Correlation 7 , 78
# Correlation 7 , 79
# Correlation 7 , 80
# Correlation 7 , 81
# Correlation 7 , 82
# Correlation 7 , 83
# Correlation 7 , 84
# Correlation 7 , 85
# Correlation 7 , 86
# Correlation 7 , 87
# Correlation 7 , 88
# Correlation 7 , 89
# Correlation 8 , 0
# Correlation 8 , 1
# Correlation 8 , 2
# Correlation 8 , 3
# Correlation 8 , 4
# Correlation 8 , 5
# Correlation 8 , 6
# Correlation 8 , 7
# Correlation 8 , 8
# Correlation 8 , 9
# Correlation 8 , 10
# Correlation 8 , 11
# Correlation 8 , 12
# Correlation 8 , 13
# Correlation 8 , 14
# Correlation 8 , 15
# Correlation 8 , 16
# Correlation 8 , 17
# Correlation 8 , 18
# Correlation 8 , 19
# Correlation 8 , 20
# Correlation 8 , 21
# Correlation 8 , 22
# Correlation 8 , 23
# Correlation 8 , 24
# Correlation 8 , 25
# Correlation 8 , 26
# Correlation 8 , 27
# Correlation 8 , 28
# Correlation 8 , 29
# Correlation 8 , 30
# Correlation 8 , 31
# Correlation 8 , 32
# Correlation 8 , 33
# Correlation 8 , 34
# Correlation 8 , 35
# Correlation 8 , 36
# Correlation 8 , 37
# Correlation 8 , 38
# Correlation 8 , 39
# Correlation 8 , 40
# Correlation 8 , 41
# Correlation 8 , 42
# Correlation 8 , 43
# Correlation 8 , 44
# Correlation 8 , 45
# Correlation 8 , 46
# Correlation 8 , 47
# Correlation 8 , 48
# Correlation 8 , 49
# Correlation 8 , 50
# Correlation 8 , 51
# Correlation 8 , 52
# Correlation 8 , 53
# Correlation 8 , 54
# Correlation 8 , 55
# Correlation 8 , 56
# Correlation 8 , 57
# Correlation 8 , 58
# Correlation 8 , 59
# Correlation 8 , 60
# Correlation 8 , 61
# Correlation 8 , 62
# Correlation 8 , 63
# Correlation 8 , 64
# Correlation 8 , 65
# Correlation 8 , 66
# Correlation 8 , 67
# Correlation 8 , 68
# Correlation 8 , 69
# Correlation 8 , 70
# Correlation 8 , 71
# Correlation 8 , 72
# Correlation 8 , 73
# Correlation 8 , 74
# Correlation 8 , 75
# Correlation 8 , 76
# Correlation 8 , 77
# Correlation 8 , 78
# Correlation 8 , 79
# Correlation 8 , 80
# Correlation 8 , 81
# Correlation 8 , 82
# Correlation 8 , 83
# Correlation 8 , 84
# Correlation 8 , 85
# Correlation 8 , 86
# Correlation 8 , 87
# Correlation 8 , 88
# Correlation 8 , 89
# Correlation 9 , 0
# Correlation 9 , 1
# Correlation 9 , 2
# Correlation 9 , 3
# Correlation 9 , 4
# Correlation 9 , 5
# Correlation 9 , 6
# Correlation 9 , 7
# Correlation 9 , 8
# Correlation 9 , 9
# Correlation 9 , 10
# Correlation 9 , 11
# Correlation 9 , 12
# Correlation 9 , 13
# Correlation 9 , 14
# Correlation 9 , 15
# Correlation 9 , 16
# Correlation 9 , 17
# Correlation 9 , 18
# Correlation 9 , 19
# Correlation 9 , 20
# Correlation 9 , 21
# Correlation 9 , 22
# Correlation 9 , 23
# Correlation 9 , 24
# Correlation 9 , 25
# Correlation 9 , 26
# Correlation 9 , 27
# Correlation 9 , 28
# Correlation 9 , 29
# Correlation 9 , 30
# Correlation 9 , 31
# Correlation 9 , 32
# Correlation 9 , 33
# Correlation 9 , 34
# Correlation 9 , 35
# Correlation 9 , 36
# Correlation 9 , 37
# Correlation 9 , 38
# Correlation 9 , 39
# Correlation 9 , 40
# Correlation 9 , 41
# Correlation 9 , 42
# Correlation 9 , 43
# Correlation 9 , 44
# Correlation 9 , 45
# Correlation 9 , 46
# Correlation 9 , 47
# Correlation 9 , 48
# Correlation 9 , 49
# Correlation 9 , 50
# Correlation 9 , 51
# Correlation 9 , 52
# Correlation 9 , 53
# Correlation 9 , 54
# Correlation 9 , 55
# Correlation 9 , 56
# Correlation 9 , 57
# Correlation 9 , 58
# Correlation 9 , 59
# Correlation 9 , 60
# Correlation 9 , 61
# Correlation 9 , 62
# Correlation 9 , 63
# Correlation 9 , 64
# Correlation 9 , 65
# Correlation 9 , 66
# Correlation 9 , 67
# Correlation 9 , 68
# Correlation 9 , 69
# Correlation 9 , 70
# Correlation 9 , 71
# Correlation 9 , 72
# Correlation 9 , 73
# Correlation 9 , 74
# Correlation 9 , 75
# Correlation 9 , 76
# Correlation 9 , 77
# Correlation 9 , 78
# Correlation 9 , 79
# Correlation 9 , 80
# Correlation 9 , 81
# Correlation 9 , 82
# Correlation 9 , 83
# Correlation 9 , 84
# Correlation 9 , 85
# Correlation 9 , 86
# Correlation 9 , 87
# Correlation 9 , 88
# Correlation 9 , 89
# Correlation 10 , 0
# Correlation 10 , 1
# Correlation 10 , 2
# Correlation 10 , 3
# Correlation 10 , 4
# Correlation 10 , 5
# Correlation 10 , 6
# Correlation 10 , 7
# Correlation 10 , 8
# Correlation 10 , 9
# Correlation 10 , 10
# Correlation 10 , 11
# Correlation 10 , 12
# Correlation 10 , 13
# Correlation 10 , 14
# Correlation 10 , 15
# Correlation 10 , 16
# Correlation 10 , 17
# Correlation 10 , 18
# Correlation 10 , 19
# Correlation 10 , 20
# Correlation 10 , 21
# Correlation 10 , 22
# Correlation 10 , 23
# Correlation 10 , 24
# Correlation 10 , 25
# Correlation 10 , 26
# Correlation 10 , 27
# Correlation 10 , 28
# Correlation 10 , 29
# Correlation 10 , 30
# Correlation 10 , 31
# Correlation 10 , 32
# Correlation 10 , 33
# Correlation 10 , 34
# Correlation 10 , 35
# Correlation 10 , 36
# Correlation 10 , 37
# Correlation 10 , 38
# Correlation 10 , 39
# Correlation 10 , 40
# Correlation 10 , 41
# Correlation 10 , 42
# Correlation 10 , 43
# Correlation 10 , 44
# Correlation 10 , 45
# Correlation 10 , 46
# Correlation 10 , 47
# Correlation 10 , 48
# Correlation 10 , 49
# Correlation 10 , 50
# Correlation 10 , 51
# Correlation 10 , 52
# Correlation 10 , 53
# Correlation 10 , 54
# Correlation 10 , 55
# Correlation 10 , 56
# Correlation 10 , 57
# Correlation 10 , 58
# Correlation 10 , 59
# Correlation 10 , 60
# Correlation 10 , 61
# Correlation 10 , 62
# Correlation 10 , 63
# Correlation 10 , 64
# Correlation 10 , 65
# Correlation 10 , 66
# Correlation 10 , 67
# Correlation 10 , 68
# Correlation 10 , 69
# Correlation 10 , 70
# Correlation 10 , 71
# Correlation 10 , 72
# Correlation 10 , 73
# Correlation 10 , 74
# Correlation 10 , 75
# Correlation 10 , 76
# Correlation 10 , 77
# Correlation 10 , 78
# Correlation 10 , 79
# Correlation 10 , 80
# Correlation 10 , 81
# Correlation 10 , 82
# Correlation 10 , 83
# Correlation 10 , 84
# Correlation 10 , 85
# Correlation 10 , 86
# Correlation 10 , 87
# Correlation 10 , 88
# Correlation 10 , 89
# Correlation 11 , 0
# Correlation 11 , 1
# Correlation 11 , 2
# Correlation 11 , 3
# Correlation 11 , 4
# Correlation 11 , 5
# Correlation 11 , 6
# Correlation 11 , 7
# Correlation 11 , 8
# Correlation 11 , 9
# Correlation 11 , 10
# Correlation 11 , 11
# Correlation 11 , 12
# Correlation 11 , 13
# Correlation 11 , 14
# Correlation 11 , 15
# Correlation 11 , 16
# Correlation 11 , 17
# Correlation 11 , 18
# Correlation 11 , 19
# Correlation 11 , 20
# Correlation 11 , 21
# Correlation 11 , 22
# Correlation 11 , 23
# Correlation 11 , 24
# Correlation 11 , 25
# Correlation 11 , 26
# Correlation 11 , 27
# Correlation 11 , 28
# Correlation 11 , 29
# Correlation 11 , 30
# Correlation 11 , 31
# Correlation 11 , 32
# Correlation 11 , 33
# Correlation 11 , 34
# Correlation 11 , 35
# Correlation 11 , 36
# Correlation 11 , 37
# Correlation 11 , 38
# Correlation 11 , 39
# Correlation 11 , 40
# Correlation 11 , 41
# Correlation 11 , 42
# Correlation 11 , 43
# Correlation 11 , 44
# Correlation 11 , 45
# Correlation 11 , 46
# Correlation 11 , 47
# Correlation 11 , 48
# Correlation 11 , 49
# Correlation 11 , 50
# Correlation 11 , 51
# Correlation 11 , 52
# Correlation 11 , 53
# Correlation 11 , 54
# Correlation 11 , 55
# Correlation 11 , 56
# Correlation 11 , 57
# Correlation 11 , 58
# Correlation 11 , 59
# Correlation 11 , 60
# Correlation 11 , 61
# Correlation 11 , 62
# Correlation 11 , 63
# Correlation 11 , 64
# Correlation 11 , 65
# Correlation 11 , 66
# Correlation 11 , 67
# Correlation 11 , 68
# Correlation 11 , 69
# Correlation 11 , 70
# Correlation 11 , 71
# Correlation 11 , 72
# Correlation 11 , 73
# Correlation 11 , 74
# Correlation 11 , 75
# Correlation 11 , 76
# Correlation 11 , 77
# Correlation 11 , 78
# Correlation 11 , 79
# Correlation 11 , 80
# Correlation 11 , 81
# Correlation 11 , 82
# Correlation 11 , 83
# Correlation 11 , 84
# Correlation 11 , 85
# Correlation 11 , 86
# Correlation 11 , 87
# Correlation 11 , 88
# Correlation 11 , 89
# Correlation 12 , 0
# Correlation 12 , 1
# Correlation 12 , 2
# Correlation 12 , 3
# Correlation 12 , 4
# Correlation 12 , 5
# Correlation 12 , 6
# Correlation 12 , 7
# Correlation 12 , 8
# Correlation 12 , 9
# Correlation 12 , 10
# Correlation 12 , 11
# Correlation 12 , 12
# Correlation 12 , 13
# Correlation 12 , 14
# Correlation 12 , 15
# Correlation 12 , 16
# Correlation 12 , 17
# Correlation 12 , 18
# Correlation 12 , 19
# Correlation 12 , 20
# Correlation 12 , 21
# Correlation 12 , 22
# Correlation 12 , 23
# Correlation 12 , 24
# Correlation 12 , 25
# Correlation 12 , 26
# Correlation 12 , 27
# Correlation 12 , 28
# Correlation 12 , 29
# Correlation 12 , 30
# Correlation 12 , 31
# Correlation 12 , 32
# Correlation 12 , 33
# Correlation 12 , 34
# Correlation 12 , 35
# Correlation 12 , 36
# Correlation 12 , 37
# Correlation 12 , 38
# Correlation 12 , 39
# Correlation 12 , 40
# Correlation 12 , 41
# Correlation 12 , 42
# Correlation 12 , 43
# Correlation 12 , 44
# Correlation 12 , 45
# Correlation 12 , 46
# Correlation 12 , 47
# Correlation 12 , 48
# Correlation 12 , 49
# Correlation 12 , 50
# Correlation 12 , 51
# Correlation 12 , 52
# Correlation 12 , 53
# Correlation 12 , 54
# Correlation 12 , 55
# Correlation 12 , 56
# Correlation 12 , 57
# Correlation 12 , 58
# Correlation 12 , 59
# Correlation 12 , 60
# Correlation 12 , 61
# Correlation 12 , 62
# Correlation 12 , 63
# Correlation 12 , 64
# Correlation 12 , 65
# Correlation 12 , 66
# Correlation 12 , 67
# Correlation 12 , 68
# Correlation 12 , 69
# Correlation 12 , 70
# Correlation 12 , 71
# Correlation 12 , 72
# Correlation 12 , 73
# Correlation 12 , 74
# Correlation 12 , 75
# Correlation 12 , 76
# Correlation 12 , 77
# Correlation 12 , 78
# Correlation 12 , 79
# Correlation 12 , 80
# Correlation 12 , 81
# Correlation 12 , 82
# Correlation 12 , 83
# Correlation 12 , 84
# Correlation 12 , 85
# Correlation 12 , 86
# Correlation 12 , 87
# Correlation 12 , 88
# Correlation 12 , 89
# Correlation 13 , 0
# Correlation 13 , 1
# Correlation 13 , 2
# Correlation 13 , 3
# Correlation 13 , 4
# Correlation 13 , 5
# Correlation 13 , 6
# Correlation 13 , 7
# Correlation 13 , 8
# Correlation 13 , 9
# Correlation 13 , 10
# Correlation 13 , 11
# Correlation 13 , 12
# Correlation 13 , 13
# Correlation 13 , 14
# Correlation 13 , 15
# Correlation 13 , 16
# Correlation 13 , 17
# Correlation 13 , 18
# Correlation 13 , 19
# Correlation 13 , 20
# Correlation 13 , 21
# Correlation 13 , 22
# Correlation 13 , 23
# Correlation 13 , 24
# Correlation 13 , 25
# Correlation 13 , 26
# Correlation 13 , 27
# Correlation 13 , 28
# Correlation 13 , 29
# Correlation 13 , 30
# Correlation 13 , 31
# Correlation 13 , 32
# Correlation 13 , 33
# Correlation 13 , 34
# Correlation 13 , 35
# Correlation 13 , 36
# Correlation 13 , 37
# Correlation 13 , 38
# Correlation 13 , 39
# Correlation 13 , 40
# Correlation 13 , 41
# Correlation 13 , 42
# Correlation 13 , 43
# Correlation 13 , 44
# Correlation 13 , 45
# Correlation 13 , 46
# Correlation 13 , 47
# Correlation 13 , 48
# Correlation 13 , 49
# Correlation 13 , 50
# Correlation 13 , 51
# Correlation 13 , 52
# Correlation 13 , 53
# Correlation 13 , 54
# Correlation 13 , 55
# Correlation 13 , 56
# Correlation 13 , 57
# Correlation 13 , 58
# Correlation 13 , 59
# Correlation 13 , 60
# Correlation 13 , 61
# Correlation 13 , 62
# Correlation 13 , 63
# Correlation 13 , 64
# Correlation 13 , 65
# Correlation 13 , 66
# Correlation 13 , 67
# Correlation 13 , 68
# Correlation 13 , 69
# Correlation 13 , 70
# Correlation 13 , 71
# Correlation 13 , 72
# Correlation 13 , 73
# Correlation 13 , 74
# Correlation 13 , 75
# Correlation 13 , 76
# Correlation 13 , 77
# Correlation 13 , 78
# Correlation 13 , 79
# Correlation 13 , 80
# Correlation 13 , 81
# Correlation 13 , 82
# Correlation 13 , 83
# Correlation 13 , 84
# Correlation 13 , 85
# Correlation 13 , 86
# Correlation 13 , 87
# Correlation 13 , 88
# Correlation 13 , 89
# Correlation 14 , 0
# Correlation 14 , 1
# Correlation 14 , 2
# Correlation 14 , 3
# Correlation 14 , 4
# Correlation 14 , 5
# Correlation 14 , 6
# Correlation 14 , 7
# Correlation 14 , 8
# Correlation 14 , 9
# Correlation 14 , 10
# Correlation 14 , 11
# Correlation 14 , 12
# Correlation 14 , 13
# Correlation 14 , 14
# Correlation 14 , 15
# Correlation 14 , 16
# Correlation 14 , 17
# Correlation 14 , 18
# Correlation 14 , 19
# Correlation 14 , 20
# Correlation 14 , 21
# Correlation 14 , 22
# Correlation 14 , 23
# Correlation 14 , 24
# Correlation 14 , 25
# Correlation 14 , 26
# Correlation 14 , 27
# Correlation 14 , 28
# Correlation 14 , 29
# Correlation 14 , 30
# Correlation 14 , 31
# Correlation 14 , 32
# Correlation 14 , 33
# Correlation 14 , 34
# Correlation 14 , 35
# Correlation 14 , 36
# Correlation 14 , 37
# Correlation 14 , 38
# Correlation 14 , 39
# Correlation 14 , 40
# Correlation 14 , 41
# Correlation 14 , 42
# Correlation 14 , 43
# Correlation 14 , 44
# Correlation 14 , 45
# Correlation 14 , 46
# Correlation 14 , 47
# Correlation 14 , 48
# Correlation 14 , 49
# Correlation 14 , 50
# Correlation 14 , 51
# Correlation 14 , 52
# Correlation 14 , 53
# Correlation 14 , 54
# Correlation 14 , 55
# Correlation 14 , 56
# Correlation 14 , 57
# Correlation 14 , 58
# Correlation 14 , 59
# Correlation 14 , 60
# Correlation 14 , 61
# Correlation 14 , 62
# Correlation 14 , 63
# Correlation 14 , 64
# Correlation 14 , 65
# Correlation 14 , 66
# Correlation 14 , 67
# Correlation 14 , 68
# Correlation 14 , 69
# Correlation 14 , 70
# Correlation 14 , 71
# Correlation 14 , 72
# Correlation 14 , 73
# Correlation 14 , 74
# Correlation 14 , 75
# Correlation 14 , 76
# Correlation 14 , 77
# Correlation 14 , 78
# Correlation 14 , 79
# Correlation 14 , 80
# Correlation 14 , 81
# Correlation 14 , 82
# Correlation 14 , 83
# Correlation 14 , 84
# Correlation 14 , 85
# Correlation 14 , 86
# Correlation 14 , 87
# Correlation 14 , 88
# Correlation 14 , 89
# Correlation 15 , 0
# Correlation 15 , 1
# Correlation 15 , 2
# Correlation 15 , 3
# Correlation 15 , 4
# Correlation 15 , 5
# Correlation 15 , 6
# Correlation 15 , 7
# Correlation 15 , 8
# Correlation 15 , 9
# Correlation 15 , 10
# Correlation 15 , 11
# Correlation 15 , 12
# Correlation 15 , 13
# Correlation 15 , 14
# Correlation 15 , 15
# Correlation 15 , 16
# Correlation 15 , 17
# Correlation 15 , 18
# Correlation 15 , 19
# Correlation 15 , 20
# Correlation 15 , 21
# Correlation 15 , 22
# Correlation 15 , 23
# Correlation 15 , 24
# Correlation 15 , 25
# Correlation 15 , 26
# Correlation 15 , 27
# Correlation 15 , 28
# Correlation 15 , 29
# Correlation 15 , 30
# Correlation 15 , 31
# Correlation 15 , 32
# Correlation 15 , 33
# Correlation 15 , 34
# Correlation 15 , 35
# Correlation 15 , 36
# Correlation 15 , 37
# Correlation 15 , 38
# Correlation 15 , 39
# Correlation 15 , 40
# Correlation 15 , 41
# Correlation 15 , 42
# Correlation 15 , 43
# Correlation 15 , 44
# Correlation 15 , 45
# Correlation 15 , 46
# Correlation 15 , 47
# Correlation 15 , 48
# Correlation 15 , 49
# Correlation 15 , 50
# Correlation 15 , 51
# Correlation 15 , 52
# Correlation 15 , 53
# Correlation 15 , 54
# Correlation 15 , 55
# Correlation 15 , 56
# Correlation 15 , 57
# Correlation 15 , 58
# Correlation 15 , 59
# Correlation 15 , 60
# Correlation 15 , 61
# Correlation 15 , 62
# Correlation 15 , 63
# Correlation 15 , 64
# Correlation 15 , 65
# Correlation 15 , 66
# Correlation 15 , 67
# Correlation 15 , 68
# Correlation 15 , 69
# Correlation 15 , 70
# Correlation 15 , 71
# Correlation 15 , 72
# Correlation 15 , 73
# Correlation 15 , 74
# Correlation 15 , 75
# Correlation 15 , 76
# Correlation 15 , 77
# Correlation 15 , 78
# Correlation 15 , 79
# Correlation 15 , 80
# Correlation 15 , 81
# Correlation 15 , 82
# Correlation 15 , 83
# Correlation 15 , 84
# Correlation 15 , 85
# Correlation 15 , 86
# Correlation 15 , 87
# Correlation 15 , 88
# Correlation 15 , 89
# Correlation 16 , 0
# Correlation 16 , 1
# Correlation 16 , 2
# Correlation 16 , 3
# Correlation 16 , 4
# Correlation 16 , 5
# Correlation 16 , 6
# Correlation 16 , 7
# Correlation 16 , 8
# Correlation 16 , 9
# Correlation 16 , 10
# Correlation 16 , 11
# Correlation 16 , 12
# Correlation 16 , 13
# Correlation 16 , 14
# Correlation 16 , 15
# Correlation 16 , 16
# Correlation 16 , 17
# Correlation 16 , 18
# Correlation 16 , 19
# Correlation 16 , 20
# Correlation 16 , 21
# Correlation 16 , 22
# Correlation 16 , 23
# Correlation 16 , 24
# Correlation 16 , 25
# Correlation 16 , 26
# Correlation 16 , 27
# Correlation 16 , 28
# Correlation 16 , 29
# Correlation 16 , 30
# Correlation 16 , 31
# Correlation 16 , 32
# Correlation 16 , 33
# Correlation 16 , 34
# Correlation 16 , 35
# Correlation 16 , 36
# Correlation 16 , 37
# Correlation 16 , 38
# Correlation 16 , 39
# Correlation 16 , 40
# Correlation 16 , 41
# Correlation 16 , 42
# Correlation 16 , 43
# Correlation 16 , 44
# Correlation 16 , 45
# Correlation 16 , 46
# Correlation 16 , 47
# Correlation 16 , 48
# Correlation 16 , 49
# Correlation 16 , 50
# Correlation 16 , 51
# Correlation 16 , 52
# Correlation 16 , 53
# Correlation 16 , 54
# Correlation 16 , 55
# Correlation 16 , 56
# Correlation 16 , 57
# Correlation 16 , 58
# Correlation 16 , 59
# Correlation 16 , 60
# Correlation 16 , 61
# Correlation 16 , 62
# Correlation 16 , 63
# Correlation 16 , 64
# Correlation 16 , 65
# Correlation 16 , 66
# Correlation 16 , 67
# Correlation 16 , 68
# Correlation 16 , 69
# Correlation 16 , 70
# Correlation 16 , 71
# Correlation 16 , 72
# Correlation 16 , 73
# Correlation 16 , 74
# Correlation 16 , 75
# Correlation 16 , 76
# Correlation 16 , 77
# Correlation 16 , 78
# Correlation 16 , 79
# Correlation 16 , 80
# Correlation 16 , 81
# Correlation 16 , 82
# Correlation 16 , 83
# Correlation 16 , 84
# Correlation 16 , 85
# Correlation 16 , 86
# Correlation 16 , 87
# Correlation 16 , 88
# Correlation 16 , 89
# Correlation 17 , 0
# Correlation 17 , 1
# Correlation 17 , 2
# Correlation 17 , 3
# Correlation 17 , 4
# Correlation 17 , 5
# Correlation 17 , 6
# Correlation 17 , 7
# Correlation 17 , 8
# Correlation 17 , 9
# Correlation 17 , 10
# Correlation 17 , 11
# Correlation 17 , 12
# Correlation 17 , 13
# Correlation 17 , 14
# Correlation 17 , 15
# Correlation 17 , 16
# Correlation 17 , 17
# Correlation 17 , 18
# Correlation 17 , 19
# Correlation 17 , 20
# Correlation 17 , 21
# Correlation 17 , 22
# Correlation 17 , 23
# Correlation 17 , 24
# Correlation 17 , 25
# Correlation 17 , 26
# Correlation 17 , 27
# Correlation 17 , 28
# Correlation 17 , 29
# Correlation 17 , 30
# Correlation 17 , 31
# Correlation 17 , 32
# Correlation 17 , 33
# Correlation 17 , 34
# Correlation 17 , 35
# Correlation 17 , 36
# Correlation 17 , 37
# Correlation 17 , 38
# Correlation 17 , 39
# Correlation 17 , 40
# Correlation 17 , 41
# Correlation 17 , 42
# Correlation 17 , 43
# Correlation 17 , 44
# Correlation 17 , 45
# Correlation 17 , 46
# Correlation 17 , 47
# Correlation 17 , 48
# Correlation 17 , 49
# Correlation 17 , 50
# Correlation 17 , 51
# Correlation 17 , 52
# Correlation 17 , 53
# Correlation 17 , 54
# Correlation 17 , 55
# Correlation 17 , 56
# Correlation 17 , 57
# Correlation 17 , 58
# Correlation 17 , 59
# Correlation 17 , 60
# Correlation 17 , 61
# Correlation 17 , 62
# Correlation 17 , 63
# Correlation 17 , 64
# Correlation 17 , 65
# Correlation 17 , 66
# Correlation 17 , 67
# Correlation 17 , 68
# Correlation 17 , 69
# Correlation 17 , 70
# Correlation 17 , 71
# Correlation 17 , 72
# Correlation 17 , 73
# Correlation 17 , 74
# Correlation 17 , 75
# Correlation 17 , 76
# Correlation 17 , 77
# Correlation 17 , 78
# Correlation 17 , 79
# Correlation 17 , 80
# Correlation 17 , 81
# Correlation 17 , 82
# Correlation 17 , 83
# Correlation 17 , 84
# Correlation 17 , 85
# Correlation 17 , 86
# Correlation 17 , 87
# Correlation 17 , 88
# Correlation 17 , 89
# Correlation 18 , 0
# Correlation 18 , 1
# Correlation 18 , 2
# Correlation 18 , 3
# Correlation 18 , 4
# Correlation 18 , 5
# Correlation 18 , 6
# Correlation 18 , 7
# Correlation 18 , 8
# Correlation 18 , 9
# Correlation 18 , 10
# Correlation 18 , 11
# Correlation 18 , 12
# Correlation 18 , 13
# Correlation 18 , 14
# Correlation 18 , 15
# Correlation 18 , 16
# Correlation 18 , 17
# Correlation 18 , 18
# Correlation 18 , 19
# Correlation 18 , 20
# Correlation 18 , 21
# Correlation 18 , 22
# Correlation 18 , 23
# Correlation 18 , 24
# Correlation 18 , 25
# Correlation 18 , 26
# Correlation 18 , 27
# Correlation 18 , 28
# Correlation 18 , 29
# Correlation 18 , 30
# Correlation 18 , 31
# Correlation 18 , 32
# Correlation 18 , 33
# Correlation 18 , 34
# Correlation 18 , 35
# Correlation 18 , 36
# Correlation 18 , 37
# Correlation 18 , 38
# Correlation 18 , 39
# Correlation 18 , 40
# Correlation 18 , 41
# Correlation 18 , 42
# Correlation 18 , 43
# Correlation 18 , 44
# Correlation 18 , 45
# Correlation 18 , 46
# Correlation 18 , 47
# Correlation 18 , 48
# Correlation 18 , 49
# Correlation 18 , 50
# Correlation 18 , 51
# Correlation 18 , 52
# Correlation 18 , 53
# Correlation 18 , 54
# Correlation 18 , 55
# Correlation 18 , 56
# Correlation 18 , 57
# Correlation 18 , 58
# Correlation 18 , 59
# Correlation 18 , 60
# Correlation 18 , 61
# Correlation 18 , 62
# Correlation 18 , 63
# Correlation 18 , 64
# Correlation 18 , 65
# Correlation 18 , 66
# Correlation 18 , 67
# Correlation 18 , 68
# Correlation 18 , 69
# Correlation 18 , 70
# Correlation 18 , 71
# Correlation 18 , 72
# Correlation 18 , 73
# Correlation 18 , 74
# Correlation 18 , 75
# Correlation 18 , 76
# Correlation 18 , 77
# Correlation 18 , 78
# Correlation 18 , 79
# Correlation 18 , 80
# Correlation 18 , 81
# Correlation 18 , 82
# Correlation 18 , 83
# Correlation 18 , 84
# Correlation 18 , 85
# Correlation 18 , 86
# Correlation 18 , 87
# Correlation 18 , 88
# Correlation 18 , 89
# Correlation 19 , 0
# Correlation 19 , 1
# Correlation 19 , 2
# Correlation 19 , 3
# Correlation 19 , 4
# Correlation 19 , 5
# Correlation 19 , 6
# Correlation 19 , 7
# Correlation 19 , 8
# Correlation 19 , 9
# Correlation 19 , 10
# Correlation 19 , 11
# Correlation 19 , 12
# Correlation 19 , 13
# Correlation 19 , 14
# Correlation 19 , 15
# Correlation 19 , 16
# Correlation 19 , 17
# Correlation 19 , 18
# Correlation 19 , 19
# Correlation 19 , 20
# Correlation 19 , 21
# Correlation 19 , 22
# Correlation 19 , 23
# Correlation 19 , 24
# Correlation 19 , 25
# Correlation 19 , 26
# Correlation 19 , 27
# Correlation 19 , 28
# Correlation 19 , 29
# Correlation 19 , 30
# Correlation 19 , 31
# Correlation 19 , 32
# Correlation 19 , 33
# Correlation 19 , 34
# Correlation 19 , 35
# Correlation 19 , 36
# Correlation 19 , 37
# Correlation 19 , 38
# Correlation 19 , 39
# Correlation 19 , 40
# Correlation 19 , 41
# Correlation 19 , 42
# Correlation 19 , 43
# Correlation 19 , 44
# Correlation 19 , 45
# Correlation 19 , 46
# Correlation 19 , 47
# Correlation 19 , 48
# Correlation 19 , 49
# Correlation 19 , 50
# Correlation 19 , 51
# Correlation 19 , 52
# Correlation 19 , 53
# Correlation 19 , 54
# Correlation 19 , 55
# Correlation 19 , 56
# Correlation 19 , 57
# Correlation 19 , 58
# Correlation 19 , 59
# Correlation 19 , 60
# Correlation 19 , 61
# Correlation 19 , 62
# Correlation 19 , 63
# Correlation 19 , 64
# Correlation 19 , 65
# Correlation 19 , 66
# Correlation 19 , 67
# Correlation 19 , 68
# Correlation 19 , 69
# Correlation 19 , 70
# Correlation 19 , 71
# Correlation 19 , 72
# Correlation 19 , 73
# Correlation 19 , 74
# Correlation 19 , 75
# Correlation 19 , 76
# Correlation 19 , 77
# Correlation 19 , 78
# Correlation 19 , 79
# Correlation 19 , 80
# Correlation 19 , 81
# Correlation 19 , 82
# Correlation 19 , 83
# Correlation 19 , 84
# Correlation 19 , 85
# Correlation 19 , 86
# Correlation 19 , 87
# Correlation 19 , 88
# Correlation 19 , 89
# Correlation 20 , 0
# Correlation 20 , 1
# Correlation 20 , 2
# Correlation 20 , 3
# Correlation 20 , 4
# Correlation 20 , 5
# Correlation 20 , 6
# Correlation 20 , 7
# Correlation 20 , 8
# Correlation 20 , 9
# Correlation 20 , 10
# Correlation 20 , 11
# Correlation 20 , 12
# Correlation 20 , 13
# Correlation 20 , 14
# Correlation 20 , 15
# Correlation 20 , 16
# Correlation 20 , 17
# Correlation 20 , 18
# Correlation 20 , 19
# Correlation 20 , 20
# Correlation 20 , 21
# Correlation 20 , 22
# Correlation 20 , 23
# Correlation 20 , 24
# Correlation 20 , 25
# Correlation 20 , 26
# Correlation 20 , 27
# Correlation 20 , 28
# Correlation 20 , 29
# Correlation 20 , 30
# Correlation 20 , 31
# Correlation 20 , 32
# Correlation 20 , 33
# Correlation 20 , 34
# Correlation 20 , 35
# Correlation 20 , 36
# Correlation 20 , 37
# Correlation 20 , 38
# Correlation 20 , 39
# Correlation 20 , 40
# Correlation 20 , 41
# Correlation 20 , 42
# Correlation 20 , 43
# Correlation 20 , 44
# Correlation 20 , 45
# Correlation 20 , 46
# Correlation 20 , 47
# Correlation 20 , 48
# Correlation 20 , 49
# Correlation 20 , 50
# Correlation 20 , 51
# Correlation 20 , 52
# Correlation 20 , 53
# Correlation 20 , 54
# Correlation 20 , 55
# Correlation 20 , 56
# Correlation 20 , 57
# Correlation 20 , 58
# Correlation 20 , 59
# Correlation 20 , 60
# Correlation 20 , 61
# Correlation 20 , 62
# Correlation 20 , 63
# Correlation 20 , 64
# Correlation 20 , 65
# Correlation 20 , 66
# Correlation 20 , 67
# Correlation 20 , 68
# Correlation 20 , 69
# Correlation 20 , 70
# Correlation 20 , 71
# Correlation 20 , 72
# Correlation 20 , 73
# Correlation 20 , 74
# Correlation 20 , 75
# Correlation 20 , 76
# Correlation 20 , 77
# Correlation 20 , 78
# Correlation 20 , 79
# Correlation 20 , 80
# Correlation 20 , 81
# Correlation 20 , 82
# Correlation 20 , 83
# Correlation 20 , 84
# Correlation 20 , 85
# Correlation 20 , 86
# Correlation 20 , 87
# Correlation 20 , 88
# Correlation 20 , 89
# Correlation 21 , 0
# Correlation 21 , 1
# Correlation 21 , 2
# Correlation 21 , 3
# Correlation 21 , 4
# Correlation 21 , 5
# Correlation 21 , 6
# Correlation 21 , 7
# Correlation 21 , 8
# Correlation 21 , 9
# Correlation 21 , 10
# Correlation 21 , 11
# Correlation 21 , 12
# Correlation 21 , 13
# Correlation 21 , 14
# Correlation 21 , 15
# Correlation 21 , 16
# Correlation 21 , 17
# Correlation 21 , 18
# Correlation 21 , 19
# Correlation 21 , 20
# Correlation 21 , 21
# Correlation 21 , 22
# Correlation 21 , 23
# Correlation 21 , 24
# Correlation 21 , 25
# Correlation 21 , 26
# Correlation 21 , 27
# Correlation 21 , 28
# Correlation 21 , 29
# Correlation 21 , 30
# Correlation 21 , 31
# Correlation 21 , 32
# Correlation 21 , 33
# Correlation 21 , 34
# Correlation 21 , 35
# Correlation 21 , 36
# Correlation 21 , 37
# Correlation 21 , 38
# Correlation 21 , 39
# Correlation 21 , 40
# Correlation 21 , 41
# Correlation 21 , 42
# Correlation 21 , 43
# Correlation 21 , 44
# Correlation 21 , 45
# Correlation 21 , 46
# Correlation 21 , 47
# Correlation 21 , 48
# Correlation 21 , 49
# Correlation 21 , 50
# Correlation 21 , 51
# Correlation 21 , 52
# Correlation 21 , 53
# Correlation 21 , 54
# Correlation 21 , 55
# Correlation 21 , 56
# Correlation 21 , 57
# Correlation 21 , 58
# Correlation 21 , 59
# Correlation 21 , 60
# Correlation 21 , 61
# Correlation 21 , 62
# Correlation 21 , 63
# Correlation 21 , 64
# Correlation 21 , 65
# Correlation 21 , 66
# Correlation 21 , 67
# Correlation 21 , 68
# Correlation 21 , 69
# Correlation 21 , 70
# Correlation 21 , 71
# Correlation 21 , 72
# Correlation 21 , 73
# Correlation 21 , 74
# Correlation 21 , 75
# Correlation 21 , 76
# Correlation 21 , 77
# Correlation 21 , 78
# Correlation 21 , 79
# Correlation 21 , 80
# Correlation 21 , 81
# Correlation 21 , 82
# Correlation 21 , 83
# Correlation 21 , 84
# Correlation 21 , 85
# Correlation 21 , 86
# Correlation 21 , 87
# Correlation 21 , 88
# Correlation 21 , 89
# Correlation 22 , 0
# Correlation 22 , 1
# Correlation 22 , 2
# Correlation 22 , 3
# Correlation 22 , 4
# Correlation 22 , 5
# Correlation 22 , 6
# Correlation 22 , 7
# Correlation 22 , 8
# Correlation 22 , 9
# Correlation 22 , 10
# Correlation 22 , 11
# Correlation 22 , 12
# Correlation 22 , 13
# Correlation 22 , 14
# Correlation 22 , 15
# Correlation 22 , 16
# Correlation 22 , 17
# Correlation 22 , 18
# Correlation 22 , 19
# Correlation 22 , 20
# Correlation 22 , 21
# Correlation 22 , 22
# Correlation 22 , 23
# Correlation 22 , 24
# Correlation 22 , 25
# Correlation 22 , 26
# Correlation 22 , 27
# Correlation 22 , 28
# Correlation 22 , 29
# Correlation 22 , 30
# Correlation 22 , 31
# Correlation 22 , 32
# Correlation 22 , 33
# Correlation 22 , 34
# Correlation 22 , 35
# Correlation 22 , 36
# Correlation 22 , 37
# Correlation 22 , 38
# Correlation 22 , 39
# Correlation 22 , 40
# Correlation 22 , 41
# Correlation 22 , 42
# Correlation 22 , 43
# Correlation 22 , 44
# Correlation 22 , 45
# Correlation 22 , 46
# Correlation 22 , 47
# Correlation 22 , 48
# Correlation 22 , 49
# Correlation 22 , 50
# Correlation 22 , 51
# Correlation 22 , 52
# Correlation 22 , 53
# Correlation 22 , 54
# Correlation 22 , 55
# Correlation 22 , 56
# Correlation 22 , 57
# Correlation 22 , 58
# Correlation 22 , 59
# Correlation 22 , 60
# Correlation 22 , 61
# Correlation 22 , 62
# Correlation 22 , 63
# Correlation 22 , 64
# Correlation 22 , 65
# Correlation 22 , 66
# Correlation 22 , 67
# Correlation 22 , 68
# Correlation 22 , 69
# Correlation 22 , 70
# Correlation 22 , 71
# Correlation 22 , 72
# Correlation 22 , 73
# Correlation 22 , 74
# Correlation 22 , 75
# ...
# Correlation 81 , 7
# Correlation 81 , 8
# Correlation 81 , 9
# Correlation 81 , 10
# Correlation 81 , 11
# Correlation 81 , 12
# Correlation 81 , 13
# Correlation 81 , 14
# Correlation 81 , 15
# Correlation 81 , 16
# Correlation 81 , 17
# Correlation 81 , 18
# Correlation 81 , 19
# Correlation 81 , 20
# Correlation 81 , 21
# Correlation 81 , 22
# Correlation 81 , 23
# Correlation 81 , 24
# Correlation 81 , 25
# Correlation 81 , 26
# Correlation 81 , 27
# Correlation 81 , 28
# Correlation 81 , 29
# Correlation 81 , 30
# Correlation 81 , 31
# Correlation 81 , 32
# Correlation 81 , 33
# Correlation 81 , 34
# Correlation 81 , 35
# Correlation 81 , 36
# Correlation 81 , 37
# Correlation 81 , 38
# Correlation 81 , 39
# Correlation 81 , 40
# Correlation 81 , 41
# Correlation 81 , 42
# Correlation 81 , 43
# Correlation 81 , 44
# Correlation 81 , 45
# Correlation 81 , 46
# Correlation 81 , 47
# Correlation 81 , 48
# Correlation 81 , 49
# Correlation 81 , 50
# Correlation 81 , 51
# Correlation 81 , 52
# Correlation 81 , 53
# Correlation 81 , 54
# Correlation 81 , 55
# Correlation 81 , 56
# Correlation 81 , 57
# Correlation 81 , 58
# Correlation 81 , 59
# Correlation 81 , 60
# Correlation 81 , 61
# Correlation 81 , 62
# Correlation 81 , 63
# Correlation 81 , 64
# Correlation 81 , 65
# Correlation 81 , 66
# Correlation 81 , 67
# Correlation 81 , 68
# Correlation 81 , 69
# Correlation 81 , 70
# Correlation 81 , 71
# Correlation 81 , 72
# Correlation 81 , 73
# Correlation 81 , 74
# Correlation 81 , 75
# Correlation 81 , 76
# Correlation 81 , 77
# Correlation 81 , 78
# Correlation 81 , 79
# Correlation 81 , 80
# Correlation 81 , 81
# Correlation 81 , 82
# Correlation 81 , 83
# Correlation 81 , 84
# Correlation 81 , 85
# Correlation 81 , 86
# Correlation 81 , 87
# Correlation 81 , 88
# Correlation 81 , 89
# Correlation 82 , 0
# Correlation 82 , 1
# Correlation 82 , 2
# Correlation 82 , 3
# Correlation 82 , 4
# Correlation 82 , 5
# Correlation 82 , 6
# Correlation 82 , 7
# Correlation 82 , 8
# Correlation 82 , 9
# Correlation 82 , 10
# Correlation 82 , 11
# Correlation 82 , 12
# Correlation 82 , 13
# Correlation 82 , 14
# Correlation 82 , 15
# Correlation 82 , 16
# Correlation 82 , 17
# Correlation 82 , 18
# Correlation 82 , 19
# Correlation 82 , 20
# Correlation 82 , 21
# Correlation 82 , 22
# Correlation 82 , 23
# Correlation 82 , 24
# Correlation 82 , 25
# Correlation 82 , 26
# Correlation 82 , 27
# Correlation 82 , 28
# Correlation 82 , 29
# Correlation 82 , 30
# Correlation 82 , 31
# Correlation 82 , 32
# Correlation 82 , 33
# Correlation 82 , 34
# Correlation 82 , 35
# Correlation 82 , 36
# Correlation 82 , 37
# Correlation 82 , 38
# Correlation 82 , 39
# Correlation 82 , 40
# Correlation 82 , 41
# Correlation 82 , 42
# Correlation 82 , 43
# Correlation 82 , 44
# Correlation 82 , 45
# Correlation 82 , 46
# Correlation 82 , 47
# Correlation 82 , 48
# Correlation 82 , 49
# Correlation 82 , 50
# Correlation 82 , 51
# Correlation 82 , 52
# Correlation 82 , 53
# Correlation 82 , 54
# Correlation 82 , 55
# Correlation 82 , 56
# Correlation 82 , 57
# Correlation 82 , 58
# Correlation 82 , 59
# Correlation 82 , 60
# Correlation 82 , 61
# Correlation 82 , 62
# Correlation 82 , 63
# Correlation 82 , 64
# Correlation 82 , 65
# Correlation 82 , 66
# Correlation 82 , 67
# Correlation 82 , 68
# Correlation 82 , 69
# Correlation 82 , 70
# Correlation 82 , 71
# Correlation 82 , 72
# Correlation 82 , 73
# Correlation 82 , 74
# Correlation 82 , 75
# Correlation 82 , 76
# Correlation 82 , 77
# Correlation 82 , 78
# Correlation 82 , 79
# Correlation 82 , 80
# Correlation 82 , 81
# Correlation 82 , 82
# Correlation 82 , 83
# Correlation 82 , 84
# Correlation 82 , 85
# Correlation 82 , 86
# Correlation 82 , 87
# Correlation 82 , 88
# Correlation 82 , 89
# Correlation 83 , 0
# Correlation 83 , 1
# Correlation 83 , 2
# Correlation 83 , 3
# Correlation 83 , 4
# Correlation 83 , 5
# Correlation 83 , 6
# Correlation 83 , 7
# Correlation 83 , 8
# Correlation 83 , 9
# Correlation 83 , 10
# Correlation 83 , 11
# Correlation 83 , 12
# Correlation 83 , 13
# Correlation 83 , 14
# Correlation 83 , 15
# Correlation 83 , 16
# Correlation 83 , 17
# Correlation 83 , 18
# Correlation 83 , 19
# Correlation 83 , 20
# Correlation 83 , 21
# Correlation 83 , 22
# Correlation 83 , 23
# Correlation 83 , 24
# Correlation 83 , 25
# Correlation 83 , 26
# Correlation 83 , 27
# Correlation 83 , 28
# Correlation 83 , 29
# Correlation 83 , 30
# Correlation 83 , 31
# Correlation 83 , 32
# Correlation 83 , 33
# Correlation 83 , 34
# Correlation 83 , 35
# Correlation 83 , 36
# Correlation 83 , 37
# Correlation 83 , 38
# Correlation 83 , 39
# Correlation 83 , 40
# Correlation 83 , 41
# Correlation 83 , 42
# Correlation 83 , 43
# Correlation 83 , 44
# Correlation 83 , 45
# Correlation 83 , 46
# Correlation 83 , 47
# Correlation 83 , 48
# Correlation 83 , 49
# Correlation 83 , 50
# Correlation 83 , 51
# Correlation 83 , 52
# Correlation 83 , 53
# Correlation 83 , 54
# Correlation 83 , 55
# Correlation 83 , 56
# Correlation 83 , 57
# Correlation 83 , 58
# Correlation 83 , 59
# Correlation 83 , 60
# Correlation 83 , 61
# Correlation 83 , 62
# Correlation 83 , 63
# Correlation 83 , 64
# Correlation 83 , 65
# Correlation 83 , 66
# Correlation 83 , 67
# Correlation 83 , 68
# Correlation 83 , 69
# Correlation 83 , 70
# Correlation 83 , 71
# Correlation 83 , 72
# Correlation 83 , 73
# Correlation 83 , 74
# Correlation 83 , 75
# Correlation 83 , 76
# Correlation 83 , 77
# Correlation 83 , 78
# Correlation 83 , 79
# Correlation 83 , 80
# Correlation 83 , 81
# Correlation 83 , 82
# Correlation 83 , 83
# Correlation 83 , 84
# Correlation 83 , 85
# Correlation 83 , 86
# Correlation 83 , 87
# Correlation 83 , 88
# Correlation 83 , 89
# Correlation 84 , 0
# Correlation 84 , 1
# Correlation 84 , 2
# Correlation 84 , 3
# Correlation 84 , 4
# Correlation 84 , 5
# Correlation 84 , 6
# Correlation 84 , 7
# Correlation 84 , 8
# Correlation 84 , 9
# Correlation 84 , 10
# Correlation 84 , 11
# Correlation 84 , 12
# Correlation 84 , 13
# Correlation 84 , 14
# Correlation 84 , 15
# Correlation 84 , 16
# Correlation 84 , 17
# Correlation 84 , 18
# Correlation 84 , 19
# Correlation 84 , 20
# Correlation 84 , 21
# Correlation 84 , 22
# Correlation 84 , 23
# Correlation 84 , 24
# Correlation 84 , 25
# Correlation 84 , 26
# Correlation 84 , 27
# Correlation 84 , 28
# Correlation 84 , 29
# Correlation 84 , 30
# Correlation 84 , 31
# Correlation 84 , 32
# Correlation 84 , 33
# Correlation 84 , 34
# Correlation 84 , 35
# Correlation 84 , 36
# Correlation 84 , 37
# Correlation 84 , 38
# Correlation 84 , 39
# Correlation 84 , 40
# Correlation 84 , 41
# Correlation 84 , 42
# Correlation 84 , 43
# Correlation 84 , 44
# Correlation 84 , 45
# Correlation 84 , 46
# Correlation 84 , 47
# Correlation 84 , 48
# Correlation 84 , 49
# Correlation 84 , 50
# Correlation 84 , 51
# Correlation 84 , 52
# Correlation 84 , 53
# Correlation 84 , 54
# Correlation 84 , 55
# Correlation 84 , 56
# Correlation 84 , 57
# Correlation 84 , 58
# Correlation 84 , 59
# Correlation 84 , 60
# Correlation 84 , 61
# Correlation 84 , 62
# Correlation 84 , 63
# Correlation 84 , 64
# Correlation 84 , 65
# Correlation 84 , 66
# Correlation 84 , 67
# Correlation 84 , 68
# Correlation 84 , 69
# Correlation 84 , 70
# Correlation 84 , 71
# Correlation 84 , 72
# Correlation 84 , 73
# Correlation 84 , 74
# Correlation 84 , 75
# Correlation 84 , 76
# Correlation 84 , 77
# Correlation 84 , 78
# Correlation 84 , 79
# Correlation 84 , 80
# Correlation 84 , 81
# Correlation 84 , 82
# Correlation 84 , 83
# Correlation 84 , 84
# Correlation 84 , 85
# Correlation 84 , 86
# Correlation 84 , 87
# Correlation 84 , 88
# Correlation 84 , 89
# Correlation 85 , 0
# Correlation 85 , 1
# Correlation 85 , 2
# Correlation 85 , 3
# Correlation 85 , 4
# Correlation 85 , 5
# Correlation 85 , 6
# Correlation 85 , 7
# Correlation 85 , 8
# Correlation 85 , 9
# Correlation 85 , 10
# Correlation 85 , 11
# Correlation 85 , 12
# Correlation 85 , 13
# Correlation 85 , 14
# Correlation 85 , 15
# Correlation 85 , 16
# Correlation 85 , 17
# Correlation 85 , 18
# Correlation 85 , 19
# Correlation 85 , 20
# Correlation 85 , 21
# Correlation 85 , 22
# Correlation 85 , 23
# Correlation 85 , 24
# Correlation 85 , 25
# Correlation 85 , 26
# Correlation 85 , 27
# Correlation 85 , 28
# Correlation 85 , 29
# Correlation 85 , 30
# Correlation 85 , 31
# Correlation 85 , 32
# Correlation 85 , 33
# Correlation 85 , 34
# Correlation 85 , 35
# Correlation 85 , 36
# Correlation 85 , 37
# Correlation 85 , 38
# Correlation 85 , 39
# Correlation 85 , 40
# Correlation 85 , 41
# Correlation 85 , 42
# Correlation 85 , 43
# Correlation 85 , 44
# Correlation 85 , 45
# Correlation 85 , 46
# Correlation 85 , 47
# Correlation 85 , 48
# Correlation 85 , 49
# Correlation 85 , 50
# Correlation 85 , 51
# Correlation 85 , 52
# Correlation 85 , 53
# Correlation 85 , 54
# Correlation 85 , 55
# Correlation 85 , 56
# Correlation 85 , 57
# Correlation 85 , 58
# Correlation 85 , 59
# Correlation 85 , 60
# Correlation 85 , 61
# Correlation 85 , 62
# Correlation 85 , 63
# Correlation 85 , 64
# Correlation 85 , 65
# Correlation 85 , 66
# Correlation 85 , 67
# Correlation 85 , 68
# Correlation 85 , 69
# Correlation 85 , 70
# Correlation 85 , 71
# Correlation 85 , 72
# Correlation 85 , 73
# Correlation 85 , 74
# Correlation 85 , 75
# Correlation 85 , 76
# Correlation 85 , 77
# Correlation 85 , 78
# Correlation 85 , 79
# Correlation 85 , 80
# Correlation 85 , 81
# Correlation 85 , 82
# Correlation 85 , 83
# Correlation 85 , 84
# Correlation 85 , 85
# Correlation 85 , 86
# Correlation 85 , 87
# Correlation 85 , 88
# Correlation 85 , 89
# Correlation 86 , 0
# Correlation 86 , 1
# Correlation 86 , 2
# Correlation 86 , 3
# Correlation 86 , 4
# Correlation 86 , 5
# Correlation 86 , 6
# Correlation 86 , 7
# Correlation 86 , 8
# Correlation 86 , 9
# Correlation 86 , 10
# Correlation 86 , 11
# Correlation 86 , 12
# Correlation 86 , 13
# Correlation 86 , 14
# Correlation 86 , 15
# Correlation 86 , 16
# Correlation 86 , 17
# Correlation 86 , 18
# Correlation 86 , 19
# Correlation 86 , 20
# Correlation 86 , 21
# Correlation 86 , 22
# Correlation 86 , 23
# Correlation 86 , 24
# Correlation 86 , 25
# Correlation 86 , 26
# Correlation 86 , 27
# Correlation 86 , 28
# Correlation 86 , 29
# Correlation 86 , 30
# Correlation 86 , 31
# Correlation 86 , 32
# Correlation 86 , 33
# Correlation 86 , 34
# Correlation 86 , 35
# Correlation 86 , 36
# Correlation 86 , 37
# Correlation 86 , 38
# Correlation 86 , 39
# Correlation 86 , 40
# Correlation 86 , 41
# Correlation 86 , 42
# Correlation 86 , 43
# Correlation 86 , 44
# Correlation 86 , 45
# Correlation 86 , 46
# Correlation 86 , 47
# Correlation 86 , 48
# Correlation 86 , 49
# Correlation 86 , 50
# Correlation 86 , 51
# Correlation 86 , 52
# Correlation 86 , 53
# Correlation 86 , 54
# Correlation 86 , 55
# Correlation 86 , 56
# Correlation 86 , 57
# Correlation 86 , 58
# Correlation 86 , 59
# Correlation 86 , 60
# Correlation 86 , 61
# Correlation 86 , 62
# Correlation 86 , 63
# Correlation 86 , 64
# Correlation 86 , 65
# Correlation 86 , 66
# Correlation 86 , 67
# Correlation 86 , 68
# Correlation 86 , 69
# Correlation 86 , 70
# Correlation 86 , 71
# Correlation 86 , 72
# Correlation 86 , 73
# Correlation 86 , 74
# Correlation 86 , 75
# Correlation 86 , 76
# Correlation 86 , 77
# Correlation 86 , 78
# Correlation 86 , 79
# Correlation 86 , 80
# Correlation 86 , 81
# Correlation 86 , 82
# Correlation 86 , 83
# Correlation 86 , 84
# Correlation 86 , 85
# Correlation 86 , 86
# Correlation 86 , 87
# Correlation 86 , 88
# Correlation 86 , 89
# Correlation 87 , 0
# Correlation 87 , 1
# Correlation 87 , 2
# Correlation 87 , 3
# Correlation 87 , 4
# Correlation 87 , 5
# Correlation 87 , 6
# Correlation 87 , 7
# Correlation 87 , 8
# Correlation 87 , 9
# Correlation 87 , 10
# Correlation 87 , 11
# Correlation 87 , 12
# Correlation 87 , 13
# Correlation 87 , 14
# Correlation 87 , 15
# Correlation 87 , 16
# Correlation 87 , 17
# Correlation 87 , 18
# Correlation 87 , 19
# Correlation 87 , 20
# Correlation 87 , 21
# Correlation 87 , 22
# Correlation 87 , 23
# Correlation 87 , 24
# Correlation 87 , 25
# Correlation 87 , 26
# Correlation 87 , 27
# Correlation 87 , 28
# Correlation 87 , 29
# Correlation 87 , 30
# Correlation 87 , 31
# Correlation 87 , 32
# Correlation 87 , 33
# Correlation 87 , 34
# Correlation 87 , 35
# Correlation 87 , 36
# Correlation 87 , 37
# Correlation 87 , 38
# Correlation 87 , 39
# Correlation 87 , 40
# Correlation 87 , 41
# Correlation 87 , 42
# Correlation 87 , 43
# Correlation 87 , 44
# Correlation 87 , 45
# Correlation 87 , 46
# Correlation 87 , 47
# Correlation 87 , 48
# Correlation 87 , 49
# Correlation 87 , 50
# Correlation 87 , 51
# Correlation 87 , 52
# Correlation 87 , 53
# Correlation 87 , 54
# Correlation 87 , 55
# Correlation 87 , 56
# Correlation 87 , 57
# Correlation 87 , 58
# Correlation 87 , 59
# Correlation 87 , 60
# Correlation 87 , 61
# Correlation 87 , 62
# Correlation 87 , 63
# Correlation 87 , 64
# Correlation 87 , 65
# Correlation 87 , 66
# Correlation 87 , 67
# Correlation 87 , 68
# Correlation 87 , 69
# Correlation 87 , 70
# Correlation 87 , 71
# Correlation 87 , 72
# Correlation 87 , 73
# Correlation 87 , 74
# Correlation 87 , 75
# Correlation 87 , 76
# Correlation 87 , 77
# Correlation 87 , 78
# Correlation 87 , 79
# Correlation 87 , 80
# Correlation 87 , 81
# Correlation 87 , 82
# Correlation 87 , 83
# Correlation 87 , 84
# Correlation 87 , 85
# Correlation 87 , 86
# Correlation 87 , 87
# Correlation 87 , 88
# Correlation 87 , 89
# Correlation 88 , 0
# Correlation 88 , 1
# Correlation 88 , 2
# Correlation 88 , 3
# Correlation 88 , 4
# Correlation 88 , 5
# Correlation 88 , 6
# Correlation 88 , 7
# Correlation 88 , 8
# Correlation 88 , 9
# Correlation 88 , 10
# Correlation 88 , 11
# Correlation 88 , 12
# Correlation 88 , 13
# Correlation 88 , 14
# Correlation 88 , 15
# Correlation 88 , 16
# Correlation 88 , 17
# Correlation 88 , 18
# Correlation 88 , 19
# Correlation 88 , 20
# Correlation 88 , 21
# Correlation 88 , 22
# Correlation 88 , 23
# Correlation 88 , 24
# Correlation 88 , 25
# Correlation 88 , 26
# Correlation 88 , 27
# Correlation 88 , 28
# Correlation 88 , 29
# Correlation 88 , 30
# Correlation 88 , 31
# Correlation 88 , 32
# Correlation 88 , 33
# Correlation 88 , 34
# Correlation 88 , 35
# Correlation 88 , 36
# Correlation 88 , 37
# Correlation 88 , 38
# Correlation 88 , 39
# Correlation 88 , 40
# Correlation 88 , 41
# Correlation 88 , 42
# Correlation 88 , 43
# Correlation 88 , 44
# Correlation 88 , 45
# Correlation 88 , 46
# Correlation 88 , 47
# Correlation 88 , 48
# Correlation 88 , 49
# Correlation 88 , 50
# Correlation 88 , 51
# Correlation 88 , 52
# Correlation 88 , 53
# Correlation 88 , 54
# Correlation 88 , 55
# Correlation 88 , 56
# Correlation 88 , 57
# Correlation 88 , 58
# Correlation 88 , 59
# Correlation 88 , 60
# Correlation 88 , 61
# Correlation 88 , 62
# Correlation 88 , 63
# Correlation 88 , 64
# Correlation 88 , 65
# Correlation 88 , 66
# Correlation 88 , 67
# Correlation 88 , 68
# Correlation 88 , 69
# Correlation 88 , 70
# Correlation 88 , 71
# Correlation 88 , 72
# Correlation 88 , 73
# Correlation 88 , 74
# Correlation 88 , 75
# Correlation 88 , 76
# Correlation 88 , 77
# Correlation 88 , 78
# Correlation 88 , 79
# Correlation 88 , 80
# Correlation 88 , 81
# Correlation 88 , 82
# Correlation 88 , 83
# Correlation 88 , 84
# Correlation 88 , 85
# Correlation 88 , 86
# Correlation 88 , 87
# Correlation 88 , 88
# Correlation 88 , 89
# Correlation 89 , 0
# Correlation 89 , 1
# Correlation 89 , 2
# Correlation 89 , 3
# Correlation 89 , 4
# Correlation 89 , 5
# Correlation 89 , 6
# Correlation 89 , 7
# Correlation 89 , 8
# Correlation 89 , 9
# Correlation 89 , 10
# Correlation 89 , 11
# Correlation 89 , 12
# Correlation 89 , 13
# Correlation 89 , 14
# Correlation 89 , 15
# Correlation 89 , 16
# Correlation 89 , 17
# Correlation 89 , 18
# Correlation 89 , 19
# Correlation 89 , 20
# Correlation 89 , 21
# Correlation 89 , 22
# Correlation 89 , 23
# Correlation 89 , 24
# Correlation 89 , 25
# Correlation 89 , 26
# Correlation 89 , 27
# Correlation 89 , 28
# Correlation 89 , 29
# Correlation 89 , 30
# Correlation 89 , 31
# Correlation 89 , 32
# Correlation 89 , 33
# Correlation 89 , 34
# Correlation 89 , 35
# Correlation 89 , 36
# Correlation 89 , 37
# Correlation 89 , 38
# Correlation 89 , 39
# Correlation 89 , 40
# Correlation 89 , 41
# Correlation 89 , 42
# Correlation 89 , 43
# Correlation 89 , 44
# Correlation 89 , 45
# Correlation 89 , 46
# Correlation 89 , 47
# Correlation 89 , 48
# Correlation 89 , 49
# Correlation 89 , 50
# Correlation 89 , 51
# Correlation 89 , 52
# Correlation 89 , 53
# Correlation 89 , 54
# Correlation 89 , 55
# Correlation 89 , 56
# Correlation 89 , 57
# Correlation 89 , 58
# Correlation 89 , 59
# Correlation 89 , 60
# Correlation 89 , 61
# Correlation 89 , 62
# Correlation 89 , 63
# Correlation 89 , 64
# Correlation 89 , 65
# Correlation 89 , 66
# Correlation 89 , 67
# Correlation 89 , 68
# Correlation 89 , 69
# Correlation 89 , 70
# Correlation 89 , 71
# Correlation 89 , 72
# Correlation 89 , 73
# Correlation 89 , 74
# Correlation 89 , 75
# Correlation 89 , 76
# Correlation 89 , 77
# Correlation 89 , 78
# Correlation 89 , 79
# Correlation 89 , 80
# Correlation 89 , 81
# Correlation 89 , 82
# Correlation 89 , 83
# Correlation 89 , 84
# Correlation 89 , 85
# Correlation 89 , 86
# Correlation 89 , 87
# Correlation 89 , 88
# Correlation 89 , 89
# Done!

# %%
from matplotlib.pyplot import imshow
pwcca_correlations = np.load('pwcca_correlations.npy')
pwcca_correlations_distance = 1 - pwcca_correlations
plt.title('Correlation Distance')
plt.xlabel('layer')
plt.xticks(ticks=[5, 15, 25, 35, 45, 55, 65, 75, 85],
           labels=[1, 2, 3, 4, 5, 6, 7, 8, 9])
plt.yticks(ticks=[5, 15, 25, 35, 45, 55, 65, 75, 85],
           labels=[1, 2, 3, 4, 5, 6, 7, 8, 9])
plt.ylabel('layer')

plt.imshow(pwcca_correlations_distance)
plt.colorbar()

# %%
# pwcca_correlations_distance.shape
from sklearn.manifold import MDS
embedding = MDS(n_components=2, dissimilarity='precomputed')

X_transformed = embedding.fit_transform(pwcca_correlations_distance.astype('float64'))
X_transformed.shape

colors = ['#f5f59d', '#f5b642', '#f58742', '#f55442', '#c940c5',
          '#b407ed', '#7d09d6', '#50017a', '#000000']
plt.plot(X_transformed[::10, 0], X_transformed[::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[1::10, 0], X_transformed[1::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[2::10, 0], X_transformed[2::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[3::10, 0], X_transformed[3::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[4::10, 0], X_transformed[4::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[5::10, 0], X_transformed[5::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[6::10, 0], X_transformed[6::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[7::10, 0], X_transformed[7::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[8::10, 0], X_transformed[8::10, 1], linestyle='-', color='black', zorder=1)
plt.plot(X_transformed[::10, 0], X_transformed[::10, 1], linestyle='-', color='black', zorder=1)

plt.scatter(X_transformed[::10, 0], X_transformed[::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[1::10, 0], X_transformed[1::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[2::10, 0], X_transformed[2::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[3::10, 0], X_transformed[3::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[4::10, 0], X_transformed[4::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[5::10, 0], X_transformed[5::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[6::10, 0], X_transformed[6::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[7::10, 0], X_transformed[7::10, 1], marker='o', color=colors, zorder=2)
plt.scatter(X_transformed[8::10, 0], X_transformed[8::10, 1], marker='o', color=colors, zorder=2)
