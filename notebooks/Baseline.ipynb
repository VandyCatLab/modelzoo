# %%
import sys
sys.path.append('../python_scripts/')
import analysis, baseline, datasets
import numpy as np
from tensorflow.keras.models import load_model

# %%
import imp
imp.reload(datasets)
# Load models and data
model = load_model('../outputs/models/factorial_perfect/w1s0.h5')
    
_, testData  = datasets.make_train_data(shuffle_seed=0)
x_predict, _ = datasets.make_predict_data(testData)
# Out:
# <module 'datasets' from '../python_scripts/datasets.py'>

# %%
x_predict
# Out:
# array([[[[ 8.54626616e-02,  1.67445150e-01, -2.28998227e+00],
#          [-5.53544995e-01,  4.79411135e-01,  1.00120647e+00],
#          [ 9.04373791e-01, -1.15483673e+00, -1.94584801e-01],
#          ...,
#          [ 6.11989644e-01, -1.59309045e+00,  9.68723647e-01],
#          [-2.56126159e-01, -5.49284711e-01,  1.95757012e+00],
#          [ 1.20941744e+00,  1.00124784e-02, -2.12209586e+00]],
#
#         [[-5.93304638e-01, -1.91038610e-01,  3.46891594e-01],
#          [-1.11111988e+00,  7.52442825e-01,  1.38028071e+00],
#          [-2.30768166e-01, -1.65743587e-01,  9.80006405e-01],
#          ...,
#          [ 1.28932485e-01,  1.32553450e+00, -2.41557461e-01],
#          [-1.13903147e+00,  5.74914364e-01,  1.92376225e+00],
#          [-5.10164324e-01,  9.31552072e-01, -4.83874090e-01]],
#
#         [[ 2.56923433e+00,  3.17383859e-01, -4.09701096e+00],
#          [-5.95747775e-02,  9.92638540e-02, -2.88744619e-01],
#          [-7.61115672e-01, -5.50727788e-01,  1.07625821e+00],
#          ...,
#          [ 4.60751860e-01,  5.26652098e-01, -1.91875718e+00],
#          [ 4.60604005e-01,  1.05648774e+00, -5.67030172e-01],
#          [ 1.33089512e-01,  1.00589069e-01, -1.15827464e+00]],
#
#         ...,
#
#         [[ 9.95897056e-01, -1.32953208e-01, -6.44028636e-01],
#          [ 2.21502523e-02, -1.46748802e+00, -9.45875957e-01],
#          [ 1.91085305e-01, -3.94328473e-01,  4.82308172e-01],
#          ...,
#          [ 1.44345035e+00,  3.81889231e-01,  4.58178469e-01],
#          [-9.90969340e-01, -1.53076142e+00, -2.83282161e+00],
#          [-5.44827235e-01,  5.32727930e-01, -8.28644225e-01]],
#
#         [[-4.51029289e-01,  1.36786537e+00, -4.89603590e-01],
#          [ 1.43597620e-01, -4.54689080e-01, -9.01882647e-01],
#          [-6.48479332e-01,  1.46825793e+00, -4.31792315e-01],
#          ...,
#          [ 3.21864339e-01, -3.00206395e+00, -8.04451737e-01],
#          [ 5.10231247e-01, -7.20190887e-01,  2.33129574e-02],
#          [ 1.28048227e+00, -1.18856825e+00, -8.81512369e-01]],
#
#         [[ 1.58156484e+00, -3.78431391e-02,  2.81285547e-02],
#          [-1.02880248e+00, -2.41588009e+00,  7.70219156e-01],
#          [ 1.28363405e-01, -1.57179100e-01, -2.88254199e-02],
#          ...,
#          [ 7.99416582e-01, -1.00160777e-01, -7.58748387e-01],
#
#         [[-3.88464895e-01, -3.46121856e-01,  8.02232096e-03],
#          [-2.15685943e-01, -5.25339036e-02, -3.17929908e-01],
#          [-3.32756330e-01,  5.33071635e-01, -3.05358375e-02],
#          ...,
#          [-1.58209190e+00, -5.49880887e-02,  4.30428717e-01],
#          [-9.25667483e-01, -2.03260514e-01, -2.50826038e-01],
#          [-3.49934010e-01, -3.15767961e-01, -2.28046084e-02]],
#
#         ...,
#
#         [[ 1.57923890e+00,  4.19312781e-01,  1.41738817e-01],
#          [ 1.27309610e+00, -1.37961944e+00,  3.00722363e-01],
#          [-2.86110978e+00,  1.96471863e+00, -7.51325787e-01],
#          ...,
#          [-2.03217488e-01, -6.43769204e-01,  6.60154230e-01],
#          [ 4.54957655e-01,  7.03397845e-02, -1.71830651e-01],
#          [-4.91125257e-01,  3.01946199e-01,  1.04027056e+00]],
#
#         [[-5.25971430e-01, -7.69761087e-02, -3.82213612e-01],
#          [ 3.42591598e-01, -6.13793012e-01,  3.98719578e-01],
#          [-4.46189670e-03,  2.84873583e-01,  3.94756816e-02],
#          ...,
#          [ 1.76085102e-01,  4.96694134e-01, -6.04741525e-01],
#          [ 1.64300858e-01, -1.32870879e-01,  8.72682376e-01],
#          [-7.73224866e-02, -3.09349919e-01, -5.14982144e-01]],
#
#         [[-4.36758686e-01, -1.95669360e-01, -5.94958019e-02],
#          [-4.45358960e-02,  4.69487219e-01,  4.70063446e-02],
#          [ 2.86861629e-01, -2.38273101e-02, -1.17573768e-01],
#          ...,
#          [ 4.09030648e-01, -1.66174809e-01, -6.51691215e-01],
#          [ 7.57631143e-02,  1.63293518e-01, -2.87346176e-01],
#          [ 2.15462510e-01,  2.93086080e-03,  7.42695775e-02]]]])

# %%
# RSA
import imp
imp.reload(baseline)
imp.reload(analysis)
imp.reload(datasets)
# zoomRSA = baseline.transform_baseline('zoom', 
#                                      model, 7,
#                                      analysis.do_rsa,
#                                      analysis.preprocess_rsa)
shiftRSA = baseline.transform_baseline('shift', 
                                      model, 7,
                                      analysis.do_rsa,
                                      analysis.preprocess_rsa)
# reflectRSA = baseline.transform_baseline('reflect', 
#                                         model, 7,
#                                         analysis.do_rsa,
#                                         analysis.preprocess_rsa)
# colorRSA = baseline.transform_baseline('color', 
#                                       model, 7,
#                                       analysis.do_rsa_from_acts,
#                                       analysis.preprocess_rsa)
    
# np.save('../outputs/baseline/reflectRSA.npy', reflectRSA)
# np.save('../outputs/baseline/colorRSA.npy', colorRSA)
# np.save('../outputs/baseline/shiftRSA.npy', shiftRSA)
# np.save('../outputs/baseline/zoomRSA.npy', zoomRSA)
# Out:
# ### Transform: shift with do_rsa
# Generating dataset
# Making train data...
# GCN...
# ZCA...
# Done!
# Making test data...
# Done!
# shape: (1000, 6912)
# num_images = 1000
# Generating dataset
# Making train data...
# GCN...
# ZCA...
# Done!
# Making test data...
# Done!
#  - Working on version 0 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.1005155062586393
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.2010310125172786
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.30154651877591787
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.4020620250345572
#  - Working on version 1 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.10079507600996383
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.19917929157700026
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.2997926367528519
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.399234433067301
#  - Working on version 2 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.10127128815395652
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.19723377704555312
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.29608304917891265
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.3942261927138304
#  - Working on version 3 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.10105078307911279
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.19528335332002134
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.2926658048549716
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.38995565709803404
#  - Working on version 4 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.09885552666858793
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.19232180226784762
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.2881403485125241
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.3833514230662431
#  - Working on version 5 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.09684091168868839
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.1881260973309029
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.28169713937016544
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.37334957848696
#  - Working on version 6 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.09505058813844558
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.18226463866438286
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.2724613361866458
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.36086463219146414
#  - Working on version 7 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.09208921034645469
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.17534091585593492
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.2644726150825497
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.3523460481121644
#  - Working on version 8 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.08674342847945898
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.16774166782823435
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.25643295082153733
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.3437153725138556
#  - Working on version 9 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.08380715942620394
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.1599784822635531
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.24610330048962903
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.33024996054365463
#  - Working on version 10 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.08221788633809698
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.15313927774856503
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.23454647132228412
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.3142767980728222
#  - Working on version 11 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.07745438077856394
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.14444910814811418
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.22422467101459634
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.3036670115751188
#  - Working on version 12 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.06895938511182945
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.1342865939848529
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.21284676132887834
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.2914222586919116
#  - Working on version 13 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.06169231817304723
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.12337196477159784
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.19865083294320515
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.272504420695839
#  - Working on version 14 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.05865629563162747
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.11622982033099075
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.1867196341063191
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.25606798952117665
#  - Working on version 15 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.05661378221144882
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.11112068869079937
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.17908333638008
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.24691388908125522
#  - Working on version 16 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.05279174055109179
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.1055547657959245
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.17162484748598184
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.23762542391169017
#  - Working on version 17 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.05146729289522164
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.10002846816394093
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.16288219578449648
# shape: (1000, 6912)
# num_images = 1000
# corr_sum: 0.2252837905303386
#  - Working on version 18 of 32
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  - Now correlating...
# shape: (1000, 6912)
# num_images = 1000

# %%
import matplotlib.pyplot as plt
plt.plot(shiftRSA)
plt.show()
plt.plot(zoomRSA)
plt.show()
plt.plot(colorRSA)

# %%
reflectRSA
# Out:
# [0.7216451669332717]

# %%
# SVCCA
imgset[0].shape[1]

# %%
# PWCCA
import matplotlib.pyplot as plt
rsa_color_list = np.load('rsa_color_list.npy')
rsa_reflect_list = np.load('rsa_reflect_list.npy')
rsa_shift_list = np.load('rsa_shift_list.npy')
rsa_zoom_list = np.load('rsa_zoom_list.npy')
for i in range(10):
    plt.plot(rsa_color_list[i])

# %%
for i in range(10):
    plt.plot(rsa_zoom_list[i])

# %%
for i in range(10):
    plt.plot(rsa_shift_list[i])

# %%
rsa_reflect_list[7]
# Out:
# array([0.89582314])

# %%
# RSA
rsa_shift_list = []
for i in range(10):
    print('\n==========')
    print('INSTANCE', i)
    print('==========')
    rsa_shift_list.append(baseline.transform_baseline(imgset, 'shift', 
                                                      models[i], 7,
                                                      baseline.do_rsa))

np.save('rsa_reflect_list.npy', rsa_reflect_list)
np.save('rsa_color_list.npy', rsa_color_list)
np.save('rsa_shift_list.npy', rsa_shift_list)
np.save('rsa_zoom_list.npy', rsa_zoom_list)

# %%
from PIL import Image
img = Image.fromarray(imgset[999])
img = img.resize((112, 112), resample=Image.BICUBIC)
img
# Out:
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7F572CF13710>

# %%
plt.imshow(imgset[999])
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-3-a0934fc2ecba> in <module>
# ----> 1 plt.imshow(imgset[999])
#
# NameError: name 'plt' is not defined

# %%
imgset = correlations.make_test_data()[0]
import matplotlib.pyplot as plt
# Out:
# Making test data...
# Done!

# %%
baseline.visualize_transform('shift', 16, imgset[105])

# %%
dim = 32
num_imgs = 1000
versions = 1
model = models[0]
rep_orig = model.predict(imgset)
rep_orig = baseline.get_rdm(rep_orig)
correlate_func = baseline.do_rsa
correlations = []
up_imgset = np.zeros((num_imgs, dim, dim, 3), dtype=np.uint8)
down_imgset = np.zeros((num_imgs, dim, dim, 3), dtype=np.uint8)
left_imgset = np.zeros((num_imgs, dim, dim, 3), dtype=np.uint8)
right_imgset = np.zeros((num_imgs, dim, dim, 3), dtype=np.uint8)
# create the gray values we use to fill in space
empty = np.zeros((dim, dim, 3)).astype(np.uint8)
empty.fill(128)
for v in range(versions):
    # Generate transformed imageset
    print(' - Working on version', v, 'of', versions)
    for i in range(num_imgs):
        img = imgset[i, :, :, :]
        up_imgset[v]    = np.concatenate([img[v:dim, :, :], empty[0:v, :, :]])
        down_imgset[v]  = np.concatenate([empty[0:v, :, :], img[0:dim - v, :, :]])
        left_imgset[v]  = np.concatenate([img[:, v:dim, :], empty[:, 0:v, :]], axis=1)
        right_imgset[v] = np.concatenate([empty[:, 0:v, :], img[:, 0:dim - v, :]], axis=1)

    # Get average of all 4 directions
    print(' - Now correlating...')
    corr_sum = 0.
    rep = model.predict(up_imgset, verbose=1)
    corr_sum += correlate_func(rep_orig, rep)
    rep = model.predict(down_imgset, verbose=1)
    corr_sum += correlate_func(rep_orig, rep)
    rep = model.predict(left_imgset, verbose=1)
    corr_sum += correlate_func(rep_orig, rep)
    rep = model.predict(right_imgset, verbose=1)
    corr_sum += correlate_func(rep_orig, rep)
    correlations.append(corr_sum / 4)
# Out:
# shape: (1000, 10)
# num_images = 1000
#  - Working on version 0 of 1
#  - Now correlating...
# 1000/1000 [==============================] - 1s 778us/sample
# shape: (1000, 10)
# num_images = 1000
# 1000/1000 [==============================] - 1s 822us/sample
# shape: (1000, 10)
# num_images = 1000
# 1000/1000 [==============================] - 1s 870us/sample
# shape: (1000, 10)
# num_images = 1000
# 1000/1000 [==============================] - 1s 855us/sample
# shape: (1000, 10)
# num_images = 1000

# %%
plt.imshow(up_imgset[0])

# %%
baseline.visualize_transform('zoom', 7, imgset[105])
