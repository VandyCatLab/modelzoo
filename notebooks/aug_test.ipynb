# %%
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../python_scripts/')
import datasets

# %%
trainData, testData = datasets.make_train_data(shuffle_seed=None, set_seed=False, augment=True)
# Out:
# Making train data...
# GCN...
# ZCA...
# Done!

# %%
for i in trainData:
    plt.imshow(i[0][0])
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
myImage = x_train[0]
myLabel = y_train[0]

# %%
newImage, newLabel = augmentData(myImage, myLabel)

# %%
plt.imshow(newImage)
